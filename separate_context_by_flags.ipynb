# %%
import pandas as pd
import os
import json

# %%
# Specify the file path
file_path = "./dataset.json"

# Load the JSON data from the file into a Python dictionary
with open(file_path, "r") as json_file:
    list = json.load(json_file)

# %%
df = pd.DataFrame(list)

def g(df):
    df['sentiment'] = df['manual_flag'].str.split(',', expand=True)[0]
    df['type'] = df['manual_flag'].str.split(',', expand=True)[1]
    df['topic'] = df['manual_flag'].str.split(',', expand=True)[2]
    df = df.drop(columns=['manual_flag'])
    return df

df = g(df.copy())
df
# Out:
#         id                                    comment_display sentiment  \
# 0     6639                                هیکل میا خیلی قشنگه  positive
# 1     6640                                  Love you guys❤️❤️  positive
# 2     6633  کروش کلی خطا کردی😂 رانینگ کردی توپ رو هی گرفتی...  positive
# 3     6629  میا مرسی خیلی دوست تو تو ناراحتی ها و ناراحتی ...  positive
# 4     6634                                   فوتبال بازی کنید   neutral
# ...    ...                                                ...       ...
# 6609  6876  عمه ام تو حال خونمون جنازش افتاده دورش جم شدن ...  negative
# 6610  6887                   توروخدا دوباره بسکت بازی کنیدددد  positive
# 6611  6889                      به خدا بسکتبال این طوری نیست🥲  negative
# 6612  6896             مرسی از جفتتون <br>خیلی شادم می کنین❤🎉  positive
# 6613  6905                   شما بهترینید✨️🫶🏻<br>شاد باشیددد🫠  positive
#
#           type       topic
# 0         null        null
# 1         null        null
# 2      opinion   the_media
# 3         null        null
# 4      command   the_media
# ...        ...         ...
# 6609   opinion       other
# 6610   opinion       other
# 6611   opinion       other
# 6612   opinion      person
# 6613   opinion      person
#
# [6614 rows x 5 columns]

# %%
ds = {}

def assign(row): #, category, label
    # print(row.comment_display)
    # print(row.sentiment)
    # print(row.sentiment.strip())
    
    ds.setdefault('sentiment', {})
    ds['sentiment'].setdefault(row.sentiment.strip(), [])

    ds.setdefault('type', {})
    ds['type'].setdefault(row.type.strip(), [])

    ds.setdefault('topic', {})
    ds['topic'].setdefault(row.topic.strip(), [])

    ds['sentiment'][row.sentiment.strip()].append(row.comment_display)
    ds['type'][row.type.strip()].append(row.comment_display)
    ds['topic'][row.topic.strip()].append(row.comment_display)

df.apply(assign, axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 6609    None
# 6610    None
# 6611    None
# 6612    None
# 6613    None
# Length: 6614, dtype: object

# %%
ds['topic']
# Out:
# {'null': ['هیکل میا خیلی قشنگه',
#   'Love you guys❤️❤️',
#   'میا مرسی خیلی دوست تو تو ناراحتی ها و ناراحتی ها کنارم بودی و خوشحالم میکنی خیلی\u200cخیلی دوست دارم',
#   'Good videos 😅',
#   'Much love soltan 😢🎉',
#   'میتونید والیبال هم بازی کنید خیلی  روحیه رو شاد میکنه❤',
#   'Good job really 😂',
#   'یعنی با ویدیو هات حالم عاااالی میشه عاشقتونم 😍🥰😌✋🏻',
#   'ااا',
#   'Nice',
#   'دوستون دارم آفرین چقدر  خوب زنگی کنید❤',
#   'میا ادمی کتابخون میا ادمی گشنه میا ادمی دلسوز هرکی موفقه لایک کنه❤😂',
#   ':)',
#   'مرسی که سرشار از حس خوبین🤍',
#   'لطفا جواب بدین 🥲',
#   '🤣🤣♥️',
#   '❤',
#   'عالی<a href="about:invalid#zCSafez"></a>👌',
#   'دیدن ویدئوهای میا و کوروش خودش یه تراپیه🥲🥺🫂',
#   'خیلی خشگلیییییی',
#   '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉',
#   'سیگار میخام',
#   'عالی',
#   '🌹👌🏽🧡به بع <br>پر انرژی',
#   'چقدر میا اسگله',
#   'پدرته😅',
#   'ایمان خداسسسسس😂',
#   'فورت نایت برید',
#   '💙💙💙💙',
#   ':) :)',
#   'عالی',
#   'عالی بود🌹🌹😂😘',
#   'اون دنیا خوش بگذره عزیزم❤️\u200d🔥☯️',
#   'Love u mia\U0001fa77\U0001fabb',
#   'خیلی خوبین آخه آدم چقدر میتونه خوب باشه ❤❤',
#   '👏👏👏',
#   'نمیدونم این کامنتو میخونید یا نه ولی کومان نماد یه شوهر عمه\u200cی کوله',
#   '❤️❤️',
#   'اخرین کامنتتتتتت شدممممم♥️♥️♥️🖤🖤🖤🤣🤣🤣',
#   'میا ویدیو ماینکرافت بزار',
#   'عالییی مثل همیهش',
#   '❤❤',
#   '@Ario _ tatality اگه رفتم که میگم بهت ولی خبرای خوبی شنیدم فعلا',
#   'باورتون میشه من توی این تابستون یه بار نرفتم شنا یا استخر 😢😢😢',
#   'چالشششش سعیییییی کننننن گریهههههه نکنییییییی بزاررررررر',
#   '❤❤❤',
#   '🤍❤️',
#   '❤',
#   'میا کوروش ایمان عشقید همتون',
#   '♥️🐥♥️🐥♥️♥️♥️',
#   'عشقی عالی',
#   'عالی بود<br>دمتون گرم❤',
#   'پونصد تایی شدنتون مبارک❤️❤️',
#   'اخر هفته ها با میا و کوروش&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;زندگی',
#   'Good job',
#   'میووووو',
#   'ایمان کوالا تو کامنتا',
#   'ویدئو ماینکرافت رو کی میزارین پس یک سال شد🥲',
#   '❤❤',
#   'Mia please accept me in Mialand .',
#   'خیلی دوستون داریم    ❤ کنید ببینن😊',
#   'تنیس برین',
#   'وای من نمیدونسم خواهر داره میااا',
#   'وای جوری که عاشق ویدیو هاتم و روزمو میسازن:&gt;&gt;&gt;&gt;&gt;',
#   'ohh this was adorable ❤',
#   'ویدیو هاتون تو کاتنت فارسی تکههه<br>مرسی که حالمونو خوب میکنین❤<br>Love you',
#   'میا میشه دنبال بهونه نباشی برای افسرده شدن؟',
#   'ممنون میشم ویدیو اخرمو ببینید❤',
#   'میا  اریگاتو ویدیوت خیلی وایب تابستونی میداد🌸🌸☘️☘️⭐🌟✨🦋🦋🦋🌟✨✨',
#   'امیدبخش ترین ویدیوها برای من❤',
#   'و منی که بسکتبالیستم و با دیدن بازی بسکتبالتون واقعا میخواستم گیره کنم 😢😢😂😂😂 موفق باشین❤❤',
#   'Perfect ❤❤❤',
#   'فوتبال',
#   'بابا این سوسول بازیا چیه افسردگی هم افسردگی های قدیم😐',
#   '❤❤❤❤❤',
#   'منی که این تابستون کلا درس خوندم یا باشگاه بودم یا مدرسه 😂',
#   'Plz onlyfans',
#   'میاجان لطفا از لوازم ارایشی برند های معروف مثل دیور و شنل و.... استفاده نکن چون اینا تست حیوانی دارن',
#   'بدترین یوتوب دنیا گند',
#   'این همه حال میکنن چی میگی تو',
#   'دوست داشتنی ترین موجودات دنیایید🤌',
#   'The golfing part should have been longerrrrr❤',
#   'سلام محمد هستم من گلف باز هستم و داخل کشور مقام دارم داخل ایران',
#   'خیلی خوب بود\U0001fae0😂',
#   '💗xo',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=12m40s">12:40</a> <br>Kimia jordan 😂❤',
#   'ویدیو و ادیت عالیهههه😍👌🏼',
#   'بعد از ۹ روز تاخیر دارم ویدیو رو میبینم 😂😂',
#   'کیمی جان تو بولینگ زیاد خوب نیستی؟ الان اینارو خوب بودی توش؟😂😂<br>پلی همین خوبه حالشو ببرید از تفریح',
#   'ولی ایمان😭🤣💀💀',
#   'حال خوب:',
#   'پر از حس خوبیییید❤️',
#   'میا مرسی که به ما انقدر انرژی میدی ما عاشقتیمم🥰🥰🥰🥰🥰😍😍😍',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=10m35s">10:35</a><br>بچه های کلاس در حال بسکتبال:',
#   'میای در حال گلف بازی کردن یکی از کیوت ترین چیزاییه که تو عمرم دیدم😭',
#   'چراغ قوه های کوروش از زندگی من بیشتر جذابیت داره-😭',
#   'بهترین یوتوبر وجود ندا...',
#   'فقط ایماااااننن🤣🤣🤣🤣🤣🤣',
#   'Nice',
#   'کیمیا خیلی خوشگلی😍❤',
#   'میا مگه قدت چند سانته؟😅',
#   'عجیبه اولین باره کامنت میتونم بزارم',
#   'عشق و احترام 🤍',
#   'عالی🔥',
#   'Nice',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=8m23s">8:23</a> داستان چیه میا کی تتو زد؟',
#   'حتی کسی تولدمو بهم تبریک نگفت هیچکس حواسش بهم نیست',
#   'تولدت مبارک',
#   'روز هامو با ویدیو شما شروع میکنم🤍✨',
#   'حس خوب = ویدیو شما ها ❤',
#   'میا همش به خاطر ذهن آدمه و تجربه هایی که تو ناخدآگاهت رفته من دقیقا مشکل تورو دارم ولی برای مهر ماه و پاییز انقدر برام اذیت کنندس که حتی توی بهار و تابستان بهش فکر میکنم که دارم نزدیک میشم به اون روزا انقدر انرژی بد دادم تمام اتفاقای بد زندگیم تو همون تایم برام میفته ولی دارم روش کار میکنم و میخام تجربه های جدید داشته باشم که اون حس بد گذشته رو از بین ببره❤❤❤',
#   'سلامتی اونایی که دو گوشی و یک تبلت دارن و از هر سه میا پلیز رو ساب کردن ❤❤❤',
#   '❤🎉',
#   '🥳🥳💥',
#   'چرا ویدیو جدید نذاشتی',
#   'یک هفته زیبا ❤',
#   '♥️♥️♥️',
#   'خسته نباشید ❤ کوروش عشقی 👑',
#   'دمتون گرم برای حس خوبی که منتقل میکنید 🫀😂',
#   'تابستون خود را چگونه گذراندید : day by day',
#   'برادرت كيه',
#   'خیلییی خوب بووود😍😍🤣با پارتنرم باهم دیدیم',
#   'به نظرم اگه می خواهید بزارید ویدیو تیک تاک بزارید',
#   'چرا رنگ و روت پریده',
#   'یک هفته  ویدیو نزاشتین نکنه کمپ کردین ؟',
#   'و منی که کل تابستان تو یوتوب بیکار میچرخم <br>.......',
#   '\u200f\u202a<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=5m28s">5:28</a>\u202c\u200f دستخط کوروش از آینده ی منم خوشگل تره😂',
#   'always mia land',
#   'میا اگه می خوای کل روزتو خراب کنی و گریه کنی <br>فیلم درخت گردو رو ببین که بر اثاث واقعیت ساخته شده <br>و خیلی ناراحت کنندس و فیلمش ایرانیه <br>حتما ببین خیلی قشنگه ❤️',
#   'میا جانمون منتظر پست جدید هستیمممم',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=11m31s">11:31</a> لعنتی چه صدای عجیبی تو پس زمینه موزیک هست فکر کردم گوشی زنگ میخوره',
#   'فقط ایمان😂😂😂',
#   'ما درکت میکنیم میا❤اگه میخوای میتونی درستو ادامه بدی البته که زندگیت به خودت مربوطه ولی برو دنبال علاقت ما درکت میکنیم 💞<br>𝐖𝐞 𝐥𝐨𝐯𝐞 𝐲𝐨𝐮𝐮𝐮💞',
#   '❤❤',
#   'کوروش و میا اعتصاب کردین؟ چند روز فیلم نمی زارین',
#   '🎉❤🎉❤🎉❤🎉',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=10m29s">10:29</a> کوروش دبل:نخوندم',
#   'تنها یوتوبرایی که اصکی نمیرن و ویدئوهاشون بهترین ویدئوهای یوتوبه❤🔥✨',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m13s">15:13</a> ایمان در سکوت کامل با تکنیک جدید برنده شد😂',
#   'دوباره جی تی ای آنلاین بزارید😊😊😊',
#   'واقعا خیلی خوب بود🥲💗',
#   'سلام میا عاشقتم خیلی دوستت دارممممممممممممممممممممممممممممممممممممممممممممممممممممممممم فقط ها میشه لطفاً وقتی قرار لایو بزاری از قبل در ویدئو ی جدید بگی که مثلاً فلان روز فلان ساعت لایو هست.<br>چون من عضو جدید هستم و خیلی دوست دارم که در یکی از لایو های قشنگت نقش داشته باشم.<br>فقط خواستم بگم خیلی دوستت دارممممممممممممممممممممممممممممممممممممممممممممممممممممممممم از تمام وجود دوستت ❤ دارممممممممممممممممممممممممممممممممممممممممممممممممممممممممم 😊🦋✨🥺💕💓',
#   'میا جون چرا واکترو نمیزاری💙🙁',
#   'و همچنان مامانم وسط ویدیوت وقتی گفتی میخوای ادامه تحصیل بدی:<br>درستو بخون افرین',
#   'میا تو بدون آرایش زیبا تری اگه قبول داری لایک کن',
#   'میا جونم سلام میشه لطفا میشه روز میا رو بسازی روز کوروش که غذا درست کردی رو یادم اومد گفتم اگه میشه روز میا رو هم بزاری',
#   'چراغ قوه کورورش »»»»»»»» بافتن موی میا',
#   'چقدر کوروش خوش خطه❤',
#   'میااا من ویدیو میخوام لطفا ویدو زود زود بزار حتا روزی ۱۰۰ ویدیو بزار لطفاً لطفاً لطفاً لطفاً لطفاً لطفاً',
#   'دیدن بسکتبال بازیکردنتون عذاب آور بود عذذذذااااااب',
#   'قسمت حوصله سربر ویدعو:آرایش کردن میا<br>قمست جذاب ویدعو:چراغ قوه های کوروش',
#   'میا مرسی که روزمو ساختین🫂',
#   'اول ویدئو موده میا دقیقا خودمه🤣💔',
#   'راستش اولین چیزی که یادم اومد این بود که <br>ببخشید که باعث نگرانی و اضطرابتون شدیم',
#   'My first comment',
#   'میا عشق می با ویدیو هات خیلی حال میکنم ❤️\u200d🩹<br>ممنون که ویدیو میزاری منو از بیکاری در میاری<br>ممنون❤️❤️❤️❤️😭😭😭',
#   'I love you so much 🥺❤<br>You make my day',
#   'همیشه بهم ویدیوهات وایب قشنگی میده و بهم انرژی میده 🥲🤌🏻',
#   'میا تو واقعا برای من در هر حالتی میدرخشی 🙂✨🤍<br>دوست دارم 🙂<br>امیدوارم همیشه موفق باشی <br>من میدونم که یه روزی بلاخره میری سر زندگی خودت و کار یوتیوب رو تموم می\u200cکنی اما من همیشه دوست دارم 🙂🤍',
#   'سلام<br>یه سوال<br>میخواستم بدونم فقط میا داخل یوتوب کانال داره؟',
#   'دو تا چنلو دارم از اول دارم میبینم <br>یکی میا و کوروش<br>یکی مستر وانشات',
#   'کوروش هم یه چنل داره که با ایمان توش ویدیو میذارن<br>خود ایمان هم یه چنل جدا داره توش ولاگ میذاره<br>نمیدونم سوالت رو درست متوجه شدم یا نه',
#   'عالی بود🤍',
#   'کیاتابسونا مو نتزرن بیان تا برن همراه سوپ که وقمیسن برن استخر بگردن ولی کول تابستون خوابن',
#   'ایمان = استیو',
#   'خیلی برام سوال شد چی وقتی دخترا ناراحتن خوش حالتون میکنه ما پسرا پول شما چی ؟',
#   'میا از مربیم خداوکیلی بهتر ای آپ زد👌😂😂',
#   'اگه تو لایو بعدی تون د لست آو آس پارت دو رو بازی کنید عالی میشه ❤❤',
#   '😉🤮🤢🤢😉🤢🤮',
#   'ایمان با کیسه ها اوج گرفت',
#   'تخته نرد',
#   'یکی از عجیب ترین شروع های ویدیو های یوتیوب بود ❤😂',
#   'میدونی تمام چیزی که میتونم بهتون بگم کیوت عسلیههههه🥞🥺🤌🏻❤️',
#   'من تازه فهمیدم میا خواهرم داره😐',
#   'میا دست چپتو تتو کردییییییییییییییییی',
#   'عام - فقط هیجایی و هیچکسی رو تو زندگیم عملا ندارم جز گوشیم پس اومدم اینجا بگم چقدر استرس دارم و چقدر حالم عجیبه برا نتایج کنکور و همین _ فقط یکم هیچ دوستی و خانواده صمیمی ای نداشتم پس اومدم اینجا . . .',
#   'یه روز خوب یه ویدیو خوب با شما بهترین ها درود بر کوروش و میا عزیز❤',
#   'خیلیییییی دوستون دارم❤❤❤❤❤',
#   'کیمیا میدونم که میدونی ولی بازم میگم ما با ویدیوهات زندگی میکنیم یعنی اگه نباشن میمیریم🧡❤',
#   'همه ی ما به یه کوروش نیاز داریم😂😂😂',
#   'ایمان کانگرو🎉',
#   'والیبال',
#   'بچه ها تو دقیقه ی ۸ و ۲۲ ثانیه بازوی میا رو نگاه کنید انگار تتو زده .......... واقعا تتو زده ؟؟؟ز؟🤐🤐🥶',
#   'عالی',
#   'عالی بوددد ولی بازی های بیشتر هم بزارید',
#   'سلام میا و کوروش امیدوارم ک این کامنت رو بخونید و باید بگم ک من یه نقاشی ازتون کشیدم ولی بلد نیستم تو جایی از یوتیوب براتون بفرستم ولی میخوام یجوری براتون بفرستم و ببینید اگه میشه لطفا هرکی که این کامنت رو میخونه یه کمکی بکنه',
#   'برگام میا بچه ی مردم مادر پدرامونه🥲میا چرا انقد تو خوبی',
#   'راستی کوروش من رفتم بستنی ممد ریش بدترین بستی عمرم رو خوردم',
#   'سلام میاعه قدرتمند و کبیر و کوروش <br>امیدوارم حالتون خوب باشه امیدوارم کامنتم را بخوانید💙',
#   'Mia Lan is grate🎉',
#   'میا والیبالم بازی کنین❤',
#   'I love you mia 💛 ❤️',
#   'awesome',
#   'من تاحالا فکر میکردم میا وکوشش خواهر وبرادران وازوشون عذر میخام 💯👍',
#   '❤️\u200d🩹🖤',
#   'میا خیلی دوست آرام',
#   '😂',
#   '❤❤❤❤❤❤',
#   'Mia va kourosh eshghan , 1402/05/20.',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=3m52s">3:52</a> 😂🥲',
#   'عاشق هفته ای هستم که با میا و کوروش شروع بشه',
#   'میا جان ویدئو جدیدت کیه؟',
#   'کورش عشق من<br>پادشاه قلب من<br>❤❤❤',
#   '# کوروش_جیمز',
#   'The kourosh king',
#   'یه ولاگ بگیرین برین شهربازی وسایلای هیجان انگیز سوار شین',
#   '😂😂',
#   'زیبا',
#   'کی دلش برا موریس تنگ شده',
#   '❤❤',
#   'من از یوتیوب سرم نمیشه کمک کنید.....<br>نمیدونم دیپس کیریپشن چیه🙂......\u200c▷ ●━━━━━━─────── ♪❤️ ㅤㅤ◁ㅤㅤ❚❚ㅤㅤ▷ㅤㅤㅤㅤ↻<br>بائییییی',
#   'الان که دقت میکنم میا خیلی وایب هرماینی رو میدههه',
#   'میالندی ها ظالم هستند😂😂😂😂😊',
#   'عادی سازی نکن',
#   'میا بیشتر حرف بزن تو ویدیو هاااا',
#   'حتما پیام شمارا بخ مخاطب می\u200cرسانم',
#   'Beautiful',
#   'ترکیپ ۳تاتون&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;',
#   'واییییی چقد خوبیدددد\U0001f979\U0001faf6🏻😭',
#   'میا چقد ناز شدههههه🥲😭✨',
#   'تازه میای گرم شی حالت کم کم خوب میشه یهو میا میگه که مرسی ازینکه ویدیویو رو دیدین خدافظ:)',
#   'Hi you are very good youtuber.<br>میا کارت فوقالعادست اگر میشه با کوروش ویدیوی fifa 23 بگیر',
#   'من خودم دوباره اسکی رو یخ تهران رفتم بدک نیستم😂 شما هم دوباره برین چون خیلی دوست دارم❤',
#   'Hi Mia, it was very good. You are the best Persian YouTube couple. I wanted to know if you and Korosh <br>are Esteghlali or Persepolis? \u200f\u202a<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=1m05s">1:05</a>\u202c\u200f<br>I wish I could see you up close😢❤❤❤❤',
#   'محو تیشرت کوروش شدممممم&gt;&gt;',
#   'دلم تنگ شده بود:))',
#   'Very good korosh, mia❤❤',
#   'Mia=dalil baray ezdevaj',
#   'ولااااگ سفر یا روتین روزانه بزار لطفا🥲😍😍',
#   'خیلیم دوستون دارم اسمم غزل میالندیممم❤❤',
#   'خیلی باحال بود پس چرا ساب نمیکنید تا 1Mبشن!!؟؟؟❤❤',
#   'عالی بودین ❤❤❤❤',
#   'عالییییییی',
#   'عالییییی',
#   'این افسردگی و بد مود بودنه رو کاملا درک میکنم چون خودمم باهاش مشکل دارم. موفق باشین❤️',
#   'Swing',
#   'عالی',
#   'ایمان کانگروی درون داره',
#   'تورو خدا زود به زودویدیو بزارید',
#   'Like.',
#   'من هروقت حالم بده ویدیو های تورو میبینم حالم خوب میشه مرسی که هستین',
#   'این پارکی که مسابقه دادید من زیاد ازش رد شدم',
#   'Love youuuuuuu❤️',
#   'الان میدونم کجا هستید',
#   '🌸',
#   'بیاین تورنتوووو',
#   'بی نظیر بود 😘',
#   'ینی فقططط بسکتبال بازی کردن کوروشششش😂😂',
#   'میا میدونستی عاشقتیم؟🥺❤',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=0m53s">0:53</a> 😂😂',
#   'کاش تایم ویدیو ها بیشتر بود🙏🏿😀',
#   'Mia and  king korosh ilove you 💋',
#   'کوروش توی بازی هاش توی دنیای واقعی برد و رورش کوروش رو چرا نمیزارییییییید😪😠',
#   'ایمان رکب خوردیم ابوسفیان 😂',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=5m40s">5:40</a> فک کردی ماه پشت ابر میمونه<br>(Kourosh zz)',
#   'بیشتر ویدیو بزار بیشتر ببینیمت',
#   'Amazing 😂❤',
#   'بهترین زووووووووووووج عااااالی 😍😍😍😍😍',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m21s">15:21</a> 😂😂😂 \u200cمردم من اینجا',
#   'میا کوروش میشه منو به فرزند خواندگی قبول کنید؟😢',
#   'نمیشه یک ویدیو بگیرید که کسایی که حیوان خونگی دارن عکس یا ویدیو یی برای شما بفرستن از حیوان خونگی شون ترو خدااااا',
#   'سلام من یه نظر داشتم اونم اینه که خیلی خوب میشد میا و کوروش برن skeap room',
#   'کوروش شبیه جورج السطار هست الان یه فیلمی تو تلویزیون پخش شد بازیگرش شبیه کوروش بود',
#   '🔥🔥🔥',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m07s">15:07</a> خیلیی باحال بوود😂😂😂❤',
#   'میاااا لطفااااا بازم ماینکرافت با کوروش بازی کنید و بزارینننننننن',
#   'حیح',
#   'آدم توی زندگی یکی رو مثل کوروش داشته باشه پیر نمیشه😅😍',
#   'XD',
#   'عشقتون پایدار اگر روزی خواستید جدا بشین من میام ونکوور و میدزدمتون و بهم میدوزمتون و میندازمتون تو اقیانوس آرام با تشکر',
#   'ماشالا چقدر کوروش خوش خطه براوو😍😅👏',
#   'میالند مهد متقلبان...',
#   'اسکلا اون بازیه اسمش سودوکوعه',
#   'Basketball legends 🔥😍😂',
#   'هفت سنگ هم بازی کنید😊😊',
#   'لطفا برین بدمینتوننن فکر کنم خیلی خوب بشه اگر ایمان هم باشه',
#   'با ایمان فوتبال بازی کنید',
#   'مثل همیشه عالی<br>با کیودی پای کلب برو کوروش هن بیار تا حالا ویدیو باهم ندادین',
#   'فقط ایمان تو کیسه🤣🤣🤣🤣🤣🤣',
#   'اخرین کامنت 😢😢😢😢😢',
#   'فقط اون تیکه ای که لانا رو خواند 😂❤',
#   'لطفا پینگ پنگ هم امتحان کنین💙💙💙',
#   'خوش به حالتون من دستم شکسته تو تابستون هیج کاری نمی تونم بکنم',
#   'دلمون براتون تنگ شده  اگر میشه ویدئو بزارید',
#   '😂وای،چه قدر خندیدم',
#   'باسن میا کل فیلم رو تحت تاثیر قرار داد',
#   'خیلی خوب بوددددددد',
#   'مامانم: چرا همش یه صدا از تو گوشیت داره تکرار میشه؟<br>+گوشی من: آی گات دن سامِر تایمززززززززز سامِر تایمززززز سدددد نسسسسسسس',
#   'اولین باره میشنوم خواهر داری😳😐همیشه حس میکردم فقط شنیدم تو ویدیوهات که یه برادر داری🤦🏻\u200d♀️',
#   'فقط اونجایی که میگه ای پدر سگ😅😂',
#   'Hi thanks',
#   'در انتظار ویدیو جدید🗿',
#   '❤',
#   'Best😊',
#   'سلام میشه وقتی ویدئوی کومان میبینیم وکامنت میخونیم نباشه بهترین روز هفته ویدئوی کومان یبار هم درمورد ویدئو نظر داده باشین',
#   'رو تیشرت کوروش کراش دارم',
#   'ساعت 6ونیم صبحه و من نشستم دارم ویدیوتونو میبینم عررر',
#   'عشق در کامنت ها موج میزند',
#   'You two are the only ones who make me feel better=))❤',
#   'چرا اقا هه توی زمین بسکتبال لخت بود',
#   'دلم کمپ میخاددددددددد.......🤍',
#   'میا من یکی از ارزو هام اینه که از نزدیک ببینمت و تو مثل خواهر بزرگی که ندارم میمونی من 11 سالمه و از پنچ سالگی با داداشم دارم ویدئو هاتو میبینم',
#   'به منم خوش گذشت❤🎉',
#   'روزمو ساختین😌🤍',
#   'برای پسران سرزمینم یه دختری عین میا آرزو میکنم( :',
#   'میا چقد بدون آرایش کیوووتیی :)))',
#   'خیلیییی قشنگگگگ و حال خوب کن بودددد مرسیییییی❤❤',
#   'چجوری انقد قشنگی\U0001f979❤',
#   'میا خیلیییییییی دوست دارممممممممممممم',
#   'چقدر داشتن ی آدم که به تحصیل اهمیت بده تو زندگیم دیده میشه،حتما ادامه تحصیل بده❤',
#   '❤',
#   'میای قدیم با موهای بلند&gt;&gt;&gt;&gt;&gt;&gt;&gt;',
#   'Day by Day خداسسسسسسس🌟🌟🌟🌟',
#   'کوروش داره با عشق و علاقه داره در مورد چراغ قوه هاش توضیح میده 😃😃😃😃<br><br>میا : 😶😶😶😶😶😶😏😏😏😏',
#   'وای تیکه ای که ایمان با اون کیسه ها مسابقه داد عالی بود چقدر خندیدم مسافت و پرواز کرد 😂😂😂توهمه چی بهترینید',
#   'کوروش ما هم مثل تو همیشه مرتب هستیم😂😂😂😂',
#   'کورش؟🗿',
#   'چرا دیگه گیمپلی نمیزاری؟',
#   'کورش دفترچه خاطرات تینیجری میا یادت نره',
#   'ilysm',
#   'خیلی بهم انرژی میدین و خوشحال میشیم با ویدئو هاتون🤍',
#   'میشه یه سری ماینکرفت هم داشته باشیم:&gt;؟',
#   'عاشقتونممم🥺💓',
#   '❤❤❤❤❤❤',
#   'بهترین\u200cچنل\u200cعمرم\u200cامید\u200cوارم\u200cهمیشه\u200cهمینجوری\u200cباشید',
#   'واییی میا نمیدونی چقدر ذوق کردممم🌝✨<br>بیشتر از دنیااا دوست دارم فرشتهههه:) ♡',
#   'I love your day by day videos.<br>You&#39;re a best cuple :)',
#   'ای گات دتت سامرتایمم ساممرتاییمم سدنسس',
#   'حالم باهاتون عالیه دمتون گرم ❤️🕊',
#   'عالی',
#   'راستش به منم واقعا خوش گذشت:)',
#   'My bro✨',
#   'بازی مایکرافت  بزار',
#   'میا و کوروش بودنتون باعث انرژی میشههههه❤️',
#   'منم دلم خواستتتت خبببب',
#   'Love that 🤍',
#   'You go girl 🤩❤️😍',
#   'هرکی موفقه میا زودتر ویدئو بزاره لایک کنه❤❤❤❤❤❤',
#   'اسکیت کفشی برین',
#   'تابستون 😢',
#   'داش اگ افسردگی داری بیا جامونو عوض کنیم 😂😂',
#   'عالی',
#   'پریدن ایمان توی کیسه باید میم بشه',
#   'راستش وقتی میا رفت توی اتاق کارشون پیش کوروش هنگ کردم گفتم اول از همه چطوری میزش تمیزه و چرا داره چیزی یاداشت میکنه 😂😂😂❤',
#   'چقد خوب شده که تایم ویدیو ها زیاد شده🎉',
#   'خیییلللی خندیدیممم😂',
#   'چرا با هم عروسی نمیکنید',
#   '😍😍😍',
#   '❤❤',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=9m05s">9:05</a> <br>فکنم منظور ایمان هفت سنگه',
#   'قشنگ بچه های اوایل دهه ی هفتاد همه این روزا دغدغه ی مشترک دارن 🥺😅',
#   'فوتبال',
#   'من نمیدونستم خواهر دارییی',
#   'ایمان کانگورو',
#   'اسمش افسر دگی نیست ، اسمش پریود شدنه',
#   'وای خدا 😂 انقد که سرِ ورزش گُلف خندیدم معده و سرم درد گرفت 😂😂😂😂😂❤',
#   'تروخدا فورت بزن',
#   'از همين الان نگا نكرده دلم گرفته ويديو تموم شده😂😂😂😂😂',
#   'کاش میشد یه میتینگ میزاشتید بیاید ایران',
#   'مرسی که هستیننننن👀💞',
#   'بلاااخرهههه عالی بود',
#   'Good',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=6m30s">6:30</a>  بخش چراغ قوه ها رو دوست دارم 😂😂❤<br>احساس میکنم واحد اندازه گیری نور بود چی بود  کوروش تازه یاد گرفته',
#   'Amazing',
#   'عه میا تو تمیز کردی اینجا رو کوروش هزار تا استوری گذاشت که خودش تمیز کرده اسمی از تو نبود 😂😂😂',
#   'You are the champion🎉',
#   'خیلی سعی میکنی منظم باشی و این نشونه اینه که یکم وسواس داری و این مشکلتو با روان شناس حل کنی راحت میشی',
#   'امریکا تموم شده تابستون 😮 کانادا نمی دونم تموم نشده  هشتم August هست میا    😂',
#   'احساس میکنم یکی از سوراخ های دماغت بزرگتره اون یکیه',
#   'بعد از پنج سال دنبال کردنتون یهو موبایلمو دزد زد و به قدری دلتنگ بودم که داشتم میمیردم<br>هقققق <br>مث همیشه عالی بوووود',
#   'Very good ❤',
#   'god bless mia <br>خداوند میا را بلیسد 🗿❤️',
#   'Love you ❤',
#   'nice😂',
#   'کلی باعث شادی مردم مشید واقعا دوستون دارم💖🙂',
#   'چقدر دیر ویدیو میزارید',
#   'واقعا مرسیی که لحظاتمونو شاد میکنید خیلیی خیلیییییییی بینهایت دوستون دارم با قدرت ادامه بدید بهترینا💖💕💜',
#   'تو کدوم شهر زندگی میکنین ؟ چون خیلی قشنگه',
#   'ولی رقص صبحگاهی میا ❤️🥲&gt;&gt;&gt;&gt;',
#   'Perfect ❤😂',
#   'It was very relaxing, I can play your video and meditate with it',
#   'خیلی خوب ممنون❤🎉🎉',
#   'میا فقط تو بسکتبال برنده شد😂',
#   'حال خوب کن ترین ویدیو دنیاااا🤩',
#   'میا خیلی خشحالم که اون حس خوبو حس کردی و واقعا خیلی من دوستتون دارم اومید وارم این کامنتو بخونی و من یک ویدیو فان درست کردم امیدوارم با دیدنش ناراحت نشی ولی من چند هفته پیش برات فرستادم و تا الان منتظر جوابتون هستم و نظرتون ریکشن تون رو خیلی دوست دارم و اولین ویدیویی که برای یک ادم معروف فرستادم من منتظر ریکشنتون بودم امیدوارم جوابمو بدی و نظرتونو بهم بگید خیلی دوستتون دارم اگر ببینیش و نظرتو بگی خیلی خشحال میشم ایدیمم بهت بدم',
#   'مثل همیشه پر از وایب مثبت😍😍💋💋',
#   'من فقط یه سوال دارم که هرچی فکر میکنم نمیتونم به جواب برسم ، دقیقا چرا توی هر ویدیو کامپیوتر ها روشنن و هیچ وقت خاموش نیست ؟ چرا ، میا و کوروش چراااااا؟😂😂😂😂😂',
#   'Thanks for a make laugh,the best couple in youtub',
#   '❤',
#   'کوروش و میا جان لوکیشن شما کجا ونکور هست دوس داشتم بیام از نزدیک ببینمتون ی چند تا راهنمایی هم خواستم از نزدیک ازتون بگیرم ممنون میشم جواب بدین <br>@mia plays<br>@kouman',
#   'میا ته چهرت شبیه ترانه علیدوستیه',
#   'مرسی از ویدیوهای قشنگتون❤❤❤❤❤باهاشون کلی انرژی میگیریم❤❤❤',
#   'k,m❤',
#   'میا تو رو خدا مثل قدیمت ویدئو بده 😍🤩<br>مثل همون ویدئو های اول 🤯\U0001fae0<br>که گیم پلی فورتنایت\U0001f979 و رمبو سیکس🥺 میزاشتی <br><br>اینقدر دلم تنگ شده تو رنبو سیکس🎮 بازی کنی😮\u200d💨 <br>با بازی ترسناک معروف مثل قدیم😬<br>ماینکرفت خدایی یوتیوبر دختر نداره فقط تو بازی میکنی و چند نفر دیگه 😅<br><br>اگه کسی یوتیوبر دختر ماینکرفت میشناسه بگید😃<br><br>یا مستری باکس هات <br>من خدایی فقط ویدئو های چیزایی که توشه رو میدیدم و میگفتم وای چه بامزه \U0001f979<br><br>یا دونیت های که شانسی میکردی 💌<br><br>حیف که دیگه مثل قدیم نیستی💔😭<br><br>ولی ممنون میشم یکم فقط یکم مثل قدیم باشی❤️\u200d🩹<br><br>اگر موافقی با حرف من لایک کن که میا ببینه و ممنون میشم میا یا بزار اسم اصلیت رو بگم کیمیا روانگر اگر این کامنت رو خوندی لایک کن تا بفهمم دیدی و برات اهمیت داشته \U0001faf6<br><br>راستی یه ویدئو بگیر برو اسم خودتو توی اینترنت سرچ کن قبلا توی یوتیوب سرچ زدی الان توی اینترنت سرچ کن🙏<br><br>امید وارم این کامنت به دست میا پلیز یا کوروش برسه🤲',
#   'خیلی اسکولید🙈❤️😁',
#   'دوستتون داریم میا و کوروش نازنین❤',
#   '۳ روز بعد از انتشار این ویدئو:<br>ویو: ۵۵۵ هزار<br>لایک: ۲۷ هزار<br>کامنت: ۶.۳ هزار<br>نتیجه: پیشرفت خوب و قوی میا<br>Love you❤️❤️❤️❤️',
#   'وااای چقدر خندیدم😂😂',
#   'عاشقتم کوروش😂😂😂😂😂ششش با اون شعر سرایت 😂😂😂👌🏻',
#   '❤',
#   'ایمان کانگورو😂😂😂😂',
#   'باورتون میشه تو این گرما تو تهران بارون اومد 😂<br>الله و اکبر سبحان الله ❤',
#   'میای عزیزم من داشتم خودکشی میکردم که گفتم بیام برای آخرین بار ویدیو هاتونو ببینم و انقد با ویدیو خنده رو لبم آوردید که دست نگه داشتم ممنونم ازتون شما جونمو نجات دادید:))',
#   'ایمان میا و کوروش بهترین ترکیب دنیان❤❤',
#   'میاااا من تازه تتو تو دیدم😮',
#   'عاشق اون قسمت شدم که ایمان اومد تو بازی😂😂',
#   'کوروش خیلی خوش خطه😀',
#   'God💙❤️',
#   'اینکه تو میگی از تابستونم لذت ببرم اینو یکی میگه که مدرسه یا دانشگاه میره مثل من بدبخت🗿💔',
#   'ولی من یه ولاگ دیگه از کمپ میخواممممم',
#   'لیبالل',
#   'کوروش و میای عزیزم ممنونم که بعد سه سال دوباره مثل برنامه کمپی که داشتید  دوباره در کنار ایمان قرار گرفتید ،بازم لطفاً از این دورهمی و کمپ ها داشته باشید 💚🙏',
#   'بعد از ۲۵۷ سال شش هزارمین کامنت تو عمرم💯💯👻👻',
#   'Very niceeeeeeee',
#   'کسایی که موافقن میا و کوروش برن استریم های بقیه رو دونیت کنن این کامنت رو لایک کنه ❤❤❤',
#   'به امید روزی که چنل میا و باز کنیم با ولاگ عروسیمون مواجه بشیم🥲🤌',
#   '☹️☹️☹️☹️سیر نمیشم از دیدن کلیپ هاتون',
#   'کاش بیشتر ویدیوهای دی بای دی بذاری بس ک عاشقشونم😍',
#   'بینتبال هم برید و مسابقه بدین خیلی باحاله❤❤😂😂',
#   'میا دوربین مخفی بگیر کوروشو اذیت کن<br>هر کی موافقه لایک کنه به دست میا برسه',
#   'کامنت آخر؟؟؟😂',
#   'میشه لطفاً ویدیو های از فورتنایت هم بزارین مرسی❤❤',
#   'ایمان مثل میگ میگ اومد 😂😂😂😂😂',
#   'بدمينتون و والیبال رو امتحان کنید ❤️<br>بهترین یوتوبر = میا و کوروش',
#   'میا حدود سه سال  پیش بود میخواستم ps4 بگیرم ولی بعد از دیدن فیلم پیانو زدنتون تصمیم گرفتم به جای ps4 پیانو بگیرم از اون موقع پیانو میزنم<br>و مرسی که زندگیمو عوض کردین',
#   'مهقسعجسعج خیلی قشنگ بددددد🎉',
#   'خیلی دوستووون دارم 😂❤️',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=12m24s">12:24</a> گنگ میا😎',
#   'خیلی خوب بود ❤مرسی که باهامون حرف میزنی 😊',
#   'انقد خوبین که فک کنم بقیه یوتویبرا دارن ادا در میارن ❤🥺',
#   'مامانم بزرگ بشه درست میشه : منو دوستام',
#   'تو رو خدا زود ویدیو بزارین بدون شما یوتیوب به درد نمیخوره و اینکه لطفا یه ویدیو بازی بزارین و من در خواست میکنم پابجی بازی کنین😢😢تا بحال هیچ پابجی بازی نکردین 😊❤❤❤',
#   '00:4<br>آهنگ موریس بود😂',
#   'روحیه تابستونی = دراگ',
#   'من بسکتبالیستی که داشتم از فشار بد بازی کردن کوروش و میا جررررر می\u200cخوردم',
#   'والیبال هم خوبه که بازی کنین👑👑',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=0m55s">0:55</a> I got that summertime, summertime SAAADNESS😂🥲',
#   'I love your videos ❤<br>Your videos are great for relaxing and chill , also I love you so much ❤️❤️❤️ thank you mia🔥',
#   'اسم بازی',
#   'استیک من پارتی',
#   'کوروش مثل بچه ها وسایل اتاقشو نشون میده😂😂😂😂',
#   'میای لندی ها بازنده هستن',
#   'نه بسکتبال لوس نیست',
#   '🎉🎉🎉🎉🎉🎉🎉',
#   'نگید که فقط منم چندین بار ولاگ های میا و کورورش رو میبینم 😂❤',
#   'بسکتبال به قبر باباش بخنده اینجوری باشه \U0001fae4',
#   'niiiice❤',
#   'مرسی که روزمون ساختید ❤<br><br><br>Thanks for video 😊😊',
#   'چقدر وایب خوبی میده ویدیو های میا و کوروش 🌙🦋',
#   '😍😍',
#   'خوبی ویدئوهای میا و کوروش اینکه شروع نشده میدونی قراره خیلی حالت خوب بشه ❤❤❤',
#   'بسکتبال به قبر باباش بخنده اینجوری باشه \U0001fae4',
#   'شروع هفته با میا و کورش طور بود بچه ها: عالییی🎉',
#   'منی که خیلی دوست دارم یکی باهام حرف بزنه ولی هیچکس نیست، ولی میا که میشینه باهامون حرف میزنه خیلی حس خوبی بهم میده :)))',
#   'فکر کنم اولین بار بود که کوروش سلام گفت😂',
#   'بچها شهریوری دارن زحمت میکشیم تو نمیدونی چه فشارایی رو ما هس دارم گاییده میشیم 🥲',
#   '😂❤️',
#   'عه گفتی موهامو سشوار نمیکشم که 🤣',
#   'مثل همیشه عالیییییی🤍خیلیی خوبین🤍✨',
#   'همه بازیایی ک کوروش تهش گفتو بریددد تنیس بولینگ بدمینتون والیبال حتی منچ😍😂',
#   'من از اون چراغ قوه ها دارم پس بیلیت کوروشتوپیامو بیارید 🗿😶',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=11m03s">11:03</a> توپه قشنگ صدای نویی میده 😂',
#   '.',
#   'چرا فک می\u200cکردم خواهر نداری😭😂',
#   'میا فنف بازی ترسناک بازی کن اما آموزشش رو ببین',
#   'تورو خدا تو ولاگ بعدی تنیس و پینگ پنگ و بولینگ بازی کنین ❤️😍👑',
#   'وقتی زندگی خعلی گ*وهه و فقط با ویدیو های میا یکم حالت خوب میشه🌚💕',
#   'الان باید یه هفته صبر کنم تا دوباره ویدیو بزارینننننتزاققیژانپمتذرا🗿🐈\u200d⬛',
#   'زنده باد پادشاه عظیم کوروش بزرگ 🗿🤝',
#   'میشه لطفا به بازی ایرانی ریونج که میگن بزرگترین رقیب کالافه ری اکت برین؟',
#   'ترو خدا یه ولاگ پینت بال بگیرید',
#   'عالی هستین بهترین زوج ❤🎉',
#   '😂😂💖',
#   'How energetic I’ve become',
#   'فقط اونجا که کوروش تو اون بازی دوم زودتر رسید 😂',
#   '😂 از ورزش صبگاهی ب رقص صبگاهی روشی جدید🎉✨',
#   'میشه بازی والیبال کنید',
#   'کانگورو درون ایمان بیدار شد😂',
#   'سلام میا جان خوبی میای فورت نایت بازی کنیم من بهت ad friend میدم اگه دوست داشتی قبول کن اسمم فکر کنم اینه stopitc _yolk9',
#   'کوروش هم اومد چه عالی دوستدارم صدای هردوتون رو بشنوم',
#   'میا که شروع می\u200cکنه گفتن این که برادرم دوسال ازم بزرگتره<br>ما که این داستان\u200cو ۶۶۵۴۳۳۴۵۶۷۸۷۶۵ بار شنیدیم و هنوزم ازش لذت می\u200cبریم ❤❤❤❤❤',
#   'خدا کنه این تابستون لعنتی زودتر تموم شه \\:',
#   '😂 سره گونیه کوشته شدم',
#   'میا خیلی قدرتمند بسکتبالو شرو کرد،عالی بوودد😂😂😂🤌🏻💕',
#   'وای ذوق ایمان موقع رسیدن یه دوربین خداست',
#   'میا خواهر دارههههه',
#   'احساس میکنم به ما بسکتبالیست فوش داد ۲۰ سال بسکتبال بازی کن نتجیش بشه ایشونی که میگه اون بازی اسمش چی بود ۵.۳.۱ نمیدونی چی',
#   'عالی',
#   'بولینگ ، فوتبال ، فوتبال دستی ، فیفا',
#   'میشه یه ویدیو بزاری تمام کتابات و معرفی کنی',
#   'قوربونتون برم:))))😂🥺😍',
#   'Perfect',
#   'دوساله دارم بسکتبال میرم اون گلی که  کوروش اول زد فول بود',
#   'عالی بود❤😂',
#   'جون چه خانمی',
#   'sepas az zahamatetoon ❤❤',
#   'وقتی می\u200cخواستین گلف بازی کنید چوبه به جا توپ می\u200cرفت 😅😅😅',
#   'سلام میا میخواستم بگم میشه یک بار یک ولاگ کامل بدون ادیت بزار بدون سانسور کوروش چون میدونم ۱ ساعت ویدئو بخاطر سانسور های کوروش ۲۰ دقیقه میشه 😂 کسایی که دارن این رو میخونن لایک کنن تا میا ببینه',
#   '❤',
#   '❤❤❤',
#   'چه دست خطی دارد پادشاهمان\u200c ❤️',
#   'چقدر بدون آرایش خوشگلی😍😍',
#   'فقط سیس ایمان تو کیسه😂',
#   'God bless you two<br>شما انگیزه و الهام بخش برای من در زندگی ام هستید',
#   'عالییی😍😍',
#   'جوری که میا کیوت و دوست\u200cداشتنیه...:))قربونت شممممم',
#   'میا موهاتو سبز بیلی آیلیشی کن 🤣😂😂',
#   'ظلم وستم میالنری ها🤣🤣🤣🤣',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=17m04s">17:04</a> LMAO, mia, the ball.',
#   'واقعا حالم با ویدیوتون خوب شد خیلی ممنونم ازتون و مرسییی میا که انقدر حرفای قشنگ و امیدوار کننده زدی اول ویدیو و واقعا حرف زدناتو دوست دارم و کوروشم که همیشه خندیدنامونو ده برابر میکنه♥️😭😂اونجایی که با ایمان سه تایی مسابقه دادین از خنده پارهه شدم😂',
#   'خیلییی دارم میااااا الگوی منییییی',
#   'میا و کوروش بهترین هستن',
#   'ایمان فقط😂😂😂😂😂😂',
#   'مثل همیشه عالییییی❤❤❤🪄✨',
#   'میا منم بسکتبال بازی می\u200cکنم <br>تو تیم تبریز <br>بازی می\u200cکنم <br>وتو شهید اقدمی و پور شریفی بازی می\u200cکنم،<br>تو مسابقاتم بازی کردم کلی <br>جایزه بردم میا بخدااا.❤😢😘🥰🏀🏀♥️',
#   'یکی از آرزوهام اینه میا کامنتم رو لایک کنه😢❤',
#   'Good',
#   'میشه برید اتاق فرار',
#   'کاش یه ویدیو بگیرین معنی تتو های کورش رو بمون بگین🥲🧡',
#   'اینکه ویدئو هاتون رو پارت بندی کردین خیلی خوب شده. البته ما همه ویدئو تونو میبینیم😉😂❤',
#   '😍😍😍😍😍😍😍❤❤❤❤❤❤❤❤',
#   'فقط میا موقع گلف😂❤',
#   'برید تنیس خاکی',
#   'قشنگممم',
#   'بهترین هفته ی عمرم💜💜💜🍧🍧',
#   'عالی با تعم پرتقالی ❤❤❤😂😂',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=9m08s">9:08</a> اسم پنج سه یکه😂',
#   'perfect',
#   'the golf part ❤😂',
#   '😢❤',
#   'سلام اگه میشه یکم ویدیو بیشتر بزارید چون حالم چند روز واقعن بده و فقط ویدیو های شما دوتا یا تو و کومان حالم رو خوب میکنه<br>و اینکه شما یکی از بهترین زوج های هستین که دیدم همه یا کات میکنن یا دعوا و رابطه هاشون به یه مو وصل ولی شما نه',
#   'سلام میا مت بسکتبالیست ام اگر شد در روبیکا یا ایتا بهم پیام بدین تابراتون ویدیو نشون بدم از بسکتبالم اینستا ندارم',
#   'عشق منی میا دمت گرم ک هسی❤❤',
#   'مای که از خوشحالی میا و کوروش و ایمان و بقیه یوتیوبرای ایرانی خوشحال میشیم 🥰 وقتی زندگی خدمونو میبینیم 😢🤢',
#   'برنده واقعی ایمانههههه😂😂 عالی بود بیست بار اون تیکه رو نگاه کردم',
#   'فقط اونجا ک کوروش گفت میا توپ 😂😂😂😂😂',
#   '💗',
#   'دوستون دارم',
#   'میا واقعا یه همچین بازی ای هست😂',
#   '❤❤❤❤❤❤',
#   'وااای خیلی خوبید😂😂😂❤',
#   'Love u guys 😍😍😍😍😍😍😍',
#   'انقدر اذیت نکن کوروش رو موقع توضیحاتش 😂😂😂😂😂 هول/ حول میشه خببببب',
#   'چرا بچه نمياريييييييين😅 بچتون خدااااااااا ميشه',
#   'عالی',
#   'یادمه تو جی تی ای  میرفتم یه همچین جایی گلف بازی میکردم😭😂😂😂😂😂😂😂قشنگگ یادش افتادم',
#   'Love you 😘',
#   'حتما اسکی رو یخ رو امتحان کنید',
#   'مثل همیشه قشنگ و عالی بود ❤<br>موفق باشین ❤',
#   'مثل همیشه قشنگ و عالی بود ❤<br>موفق باشین ❤',
#   'فقط منم که نمیدونستم میا خواهر داره؟',
#   'Nice 🙂',
#   'عای گات دت سامرتایممم<br>سامرتاوویمم سدنسس..',
#   'بسکتبال بهترینه😭😂',
#   'دلم یه زن مثل میا میخواد',
#   'فقط گیتارای پشت سر کوروش',
#   'چراااااا به چراغ قوه هاش دقت نمیکنی؟....دخترا همینن اصلا ما پسرا رو درک نمیکنن🥲',
#   '☕🖤',
#   'میااات عاشقتممم نروخدا لایکم کن <br>ارزومه🥺عاشقتممممم\U0001fa75💋💋 و همچنین کوروش\U0001fa75بهترین زوج',
#   'خواهر داری🤯',
#   'تابستون با ما کوروش همون اولش😂😂',
#   'کوروش فهمیدی جیسو قرار میزاره و رل زده یعنی ما دیگه یدونه ستاره هم تو این آسمون نداریم اشکال نداره جنی هست مهین هم هست گوه جون هست میا هم حالا بگیم هست گناه داره گفتم بت بگم شاید خبرا بهت نرسیده باشه بازم گفتم بهت بگم نگران نباشی داش😂😂\U0001fae0🔪',
#   'خیلی دوستتون دارم:)🥲🤍',
#   'خواهر داشتی مگه😂',
#   'میا برو ببنین چخبره از دراما ها تا عکس های .... از چنل PYnews',
#   'ام.. میا خواهر داشت؟؛///',
#   'رفع خستگی=ویدئوهای میا',
#   'تراپی؟:) نه ممنون من کومان و میارو دارم',
#   'کلا هیچ وقت اون سامرتایم سدنس رو تجربه نکردم<br>مخصوصا امسال<br>شاید واسه اینکه اخرین تابستونم قبل کنکوره🤡',
#   '❤❤',
#   'بالاخره اون عقرب و ملخ های که ایمان میخورد یه جایی تاثیر داشت 😂',
#   'خیلی خیلی ممنونم ازت چند روزی مادرم به دلایلی پیش من نبود خیلی زهنم درگیر بود ولی تو منو یاد مامانم میندازی کارات،حرفات و کلا بابت همه چی ازت ممنونم❤❤',
#   'پنج سه یک می\u200c زدیم با دیسک\u200cمن سونی؟ :)',
#   'سر بازی گلف به اندازه ۱۰ دیقه خندیدم😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂',
#   'اگه میا کامنتمو لایک کنه میالندی میشم و ادم میشم🗿',
#   'امشب تولدمه میا خیلی خوشحال میشم منو پین کنی🥳🥲',
#   'همیشه درجه یک 💎',
#   'Perfect',
#   'بازیی که ایمان میگه اینجوریه : اول از یه فاصله دور بازی شروع میشه. از اونجا شوت میکنی اگه بره داخل ۵ امتیاز میگیری. وگرنه باید قبل از لینکه توپ به زمین بخوره(این قانون رو میشه قبل از دومین برخورد توپ به زمین گذاشت ) باید بگیریش و از اونجا شوت کنی. اگه بره ۳ امتیاز میگیری وگرنه دوباره توپو قبل برخورد به زمین میگیری شوت میکنی اگه بره ۱ امتیاز میگیری وگرنه نوبت بعدیه',
#   'وااایییی...فقط اونجاش که میگه من قهرمان توپ بزرگم😂😂😂دمت گرم میا و کوروش',
#   'دلم هون توپرو میخاااد',
#   'بچه ها بچه ها میا تو زیرنویس هم داره حرف میزنه باهامون وای :))<br><a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=6m13s">6:13</a>',
#   'ماهم دوستون داریم کلی کلی کلییی❤',
#   'باید با ویدیوهای میا انگلیسی تمرین کنم پسر عالیه!',
#   'کیوت تریناااا',
#   'میا ی ویدئو هم از skin care که داری بزار',
#   'Love you 😘😘❤',
#   'بالاخره یکیو پیدا کردم که تو تابستون مودیه و تنها نیستم🤝🗿',
#   'Miaaa gameplay fortnite begir baramon😢😢❤',
#   'تنها کسایی که تو بسکتبال کاراته می کنن رو معرفی می کنم:',
#   'میا منم افسردگی اینجوری دارم',
#   'بریم کوروش رو بلند کنیم، تهه',
#   'عالی بود خدایا وای',
#   'the best❤❤❤❤❤❤❤❤❤',
#   '۱هفته پیش تولدم بود بابت کادو ممنون❤❤❤❤❤❤🧡🧡🧡🧡🧡💛💛💛💛💛💚💚💚💚💙💙💙💙💙💙💜💜💜💙🤎🤎🖤💙💙💙💙💙💚💚💚',
#   'تاحالا 10 بار این قسمت رو دیدم',
#   '🤩🤩🤩',
#   'چطور بعد چند سال تازه فهمیدم میا خواهر داره !!!',
#   'میا چقد چهره قشنگتر میشه وقتی موهاتو میبندی یا میبافی🥺',
#   'وای لطفا بدمينتون بازی کنید🥺🥺',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m13s">15:13</a> ایمان آماده بود😂😂',
#   '❤❤love you Mia',
#   'Good',
#   '❤❤❤',
#   'سلام کسری هستم تا اینجا تعداد کلمات (کار تابستونی) =۴۲۵',
#   'میا بچه بیارینننن',
#   'والیبال بذارین',
#   'للان دیکه متمعن شودم که ایمان تو هر کاری برندست😂❤',
#   '❤❤❤❤',
#   'وای میا و کوروش شما دو تا بهترینین هر دفعه ویدئو هاتون رو میبینم خنده رو لبام برفراشته میشه کاش هر روز ویدیو بدین',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=13m13s">13:13</a> اين من دراوردي نيستا😂',
#   'ایمان و بیشتر تو ویدیو بیارید 😂😂<br>خیلی همتون عشقید😍❤️',
#   'لطفااااا برین پاتیناژ ❤❤❤❤❤❤❤',
#   'Mia when you upload new video I watch it on TV with my parents and my mom love you💗 . Thanks a zillion for your videos💜💕😘',
#   'پادشاه دوست داریم🙂🌸 <a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=21m00s">21:00</a>',
#   'best',
#   'عالی بووود 😂😂😂😂',
#   'بیچاره ایمانو چرا مسخره میکنین بازی ۵-۳-۱ هستش بابا فقط شوت زدنه تو سه ضرب 😂😂',
#   'آخه این بسکتبال شما بازی میکنین🤣🤣',
#   'میشه چنتا کتاب معرفی بکنید',
#   'والیباللللل',
#   'PLEEEEAAASSSSSEEEEE GO ICE SKATING ❤❤❤❤',
#   'من خودم بسکتبالیستم😊<br>میا باید پاهات مساوی و موازی باشه <br>و نحوه\u200cی شوتتون هم اشتباه بود😅',
#   'آبرو بسکتبالو بردین',
#   'Sultan Kourosh is always the winner in our hearts👑🤍',
#   'بازی های کوروش بهترینه',
#   'میا میشه زیرنویس نذاری',
#   'منی که کل تابستون دارم درس میخونم عین بچگی تو😩',
#   'وایب ویدئو های میا و کوروش&gt;&gt;&gt;&gt;&gt;بقیه',
#   'بچه خو ایران من دیگه می تونم بدون فیلتر شکن وارد یوتیوب بشم',
#   'منی که تا موقعی که حس تابستون گرفتم مدرسه شروع شد🥲',
#   'ایمانو از وسط ولاگ خرس خورد؟',
#   'پودر شدم😂😂',
#   'Perfect',
#   '😂😂❤',
#   'Oh my Goddd thank you so much for subtitles!',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m09s">15:09</a> وااای ایمانننننن 🤣🤣🤣🤣🤣🤣🤣🤣🤣',
#   'یه ویدیو رکورد کنین از بازی های چرتو پرت',
#   'میاااا احساس میکنم تو این ویدیو بوی شامپو خرسی گلرنگ میدی🥺🤣🤣<br>عاشقتونم❤',
#   'میا خواهر داشت تا الان من نمی\u200cدونستم ......🙂',
#   'Hot کورش summer forever',
#   'تنها یوتیوبر هایی هستید که میتونم بدون خستگی هزار بار یه ویدیوتون رو ببینم و برام تکراری نشه <br>واقعا مرسی ❤️\u200d🔥🥰',
#   'Thank god for these both legends , ilysm ❤️',
#   'We love day by day videos',
#   'مرسی که دوباره توی ولاگ\u200cهات باهامون حرف می\u200cزنی، خیلی لذت بخشه<br>خیلییی دوستون داریم',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=13m48s">13:48</a> وایی میا عاشقتم تو کیسه گیر کردی 🤣🤣🤣🤣',
#   'زیبا و دوست داشتنی',
#   '😂😂😂چه خفن بود',
#   'Love you both 🗿🤍🤍🤍',
#   '❤️❤️👍🏻👍🏻',
#   'حس خوب ☕',
#   'میا موقع گلف 😂😂😂😂🤍',
#   '😂😂قیافه ایمان موقع کیسه بازی 😂😂😂😂😂😂',
#   'فرح بخش',
#   'در یک جمله زندگی من تو شما دوتا خلاصه میشه:)',
#   'اتاق فرار برید',
#   'میدونم که انرژی کامنت منفیا بیشتره ولی خیلی حس خوبی میدین بهم سالهاست که نگاتون میکنم و حس میکنم خونوادمین امیدوارم که بتونم ی روزی همین حس های خوبی ک بهم دادینو بهتون برگردونم <br><br>برام یوتوب اگه چنتا قسمت مهم  داشته باشه یکی از قسمت های مهمش شما دوتا هستین کلییی ❤❤❤❤❤❤براتون',
#   'نوکرتم',
#   'اون بازی اسکش ۵ ۳ ۱ عههههایمان درست میگفت',
#   'Bah bahhhhh ❤',
#   'تنها کسی که وقتی حالم بده با ویدیو هاش آرامش میگیرم',
#   'عاشقتونم آخ ک چقد وایبتون خوبه حال ادمو خوب میکنید همیشه',
#   'کامنت اول تخسیر شد',
#   'گوه گیجه اشتباهه <br>درستش گو گیجه یا گاو گیجس که تو مازندران میگن 😅',
#   'خیلی ممنونم از شما و کورش عزیز بابت ساخت این ویدیو فرحبخش و بهشتی ❤<br>به مرتضی سلام برسونید',
#   'You are amazing',
#   'میا میشه اسکیت روی یخ هم بری🐩🍚',
#   'از بچگی به دخترهایی خر خون نخبه حس خوبی نداشتم',
#   'هیهیهیهی',
#   'عالی بود😂😂😂💖💖',
#   'سلام. میا جون... وقتی شنیدم شما توبچگی تو اوج تابستان درس می خواندی به عنوان یک دهه شصتی بدجور شکنجه روحی شدم',
#   'Perfect 🤩👏',
#   'keep it up you rock it love u',
#   'اسکیت هم بازی کنیننننن',
#   'بدمینتون بازی کنینننننن',
#   'بهترین بسکتبالیست وجود ندار...😂😂',
#   'از بچگی به دخترهایی خر خون نخبه حس خوبی نداشتم',
#   'والیبال هم برین 😁',
#   'The best 😂😂😂😂',
#   'عااااشق گلف بازی کردنتونمممممم عالیهههههه😂😂😂😂😂😂😂😂😂😂😂',
#   'فقط اونجا که ایمان اومد تو اون کیسه یهو زد جلو😂😂😂😂😂😂😂😂😂😂😂🌿',
#   'وااای مردم از بس خندیدم<br>خیییلی خوبین😂😂😂😂😂😂😂😂',
#   'میا برنده نشد برنده سلطان کوروش',
#   'جیگررر تریناااا',
#   'چرا فورتنایت نمیرید... دلمون تنگ شده😢',
#   'کوروش حرومت🤣',
#   'the Best video!!! :D thank you lovely Mia and Korosh and Iman🤍✨🌝 I love youuu',
#   'منم افسردگی دارم خیلی خوبه ک ازش گذشتی',
#   'زندگی دو تا دوست مثل میا و کوروش به من بدهکاره😭💗',
#   'میا یک ویدئو مجازاتی باحال بزارید لطفا',
#   '❤❤❤❤❤❤❤❤❤❤',
#   '❤❤',
#   'میتونیم اسکار قشنگترین و باحال ترین کاپل دنیارو بدیم به شما\U0001fae0🥺',
#   '❤❤❤',
#   'نووووو',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=5m55s">5:55</a> فقط صفحه دسکتاپ کوروش و میا رو مقایسه کنین😂😂',
#   '<a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a>',
#   'واااااای ایمان 😂😂😂😂 مردم من از خنده',
#   'این ۲۱ دقیقه انگار ۱۰ ثانیه بود',
#   'دیشب خواب دیدم عروسی گرفتید فنا هم دعوتن واااای😂💕💕',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=19m40s">19:40</a> و <a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=16m35s">16:35</a> 😆😆😆🤌',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m16s">15:16</a> ایمان با یه حرکت کرم\u200cگونه همه رو نابود کرد😂😂😂',
#   'اگه یروز ببینم دیگه ویدیو نمیذارید یا با هم نیستید ، پا میشم پیداتون میکنم و میکشمتون 😊 باهم خیلی خوبید',
#   '😂😂😂',
#   'اون تیکه اولش که حرف میزنی رو خیلی دوست دارم.میا لطفا بیشتر حرف بزن برامون <br>البته اگر دوست داری🥰🥰🥰🥰💞💞💞💞💞💞💞',
#   'Awli',
#   'لانا؟؟؟ نه مرسی ما میا رو داریم',
#   'روزمو ساختین،خیلی خندیدم مرسی واقعا🤣\U0001f979❤️✨',
#   'بمیرم برات ایمان که فیلم بردار شدی',
#   'ایمان سوت شد😂',
#   'یه روزی میشه که ما باید شما رو به بچه ها معرفی کنیم🥲💓',
#   'منی که هروز دو تا ویدیو باید از میا و کوروش ببینم ❤',
#   'سلطان کوروش😂',
#   'بهترین یوتیوبر ایرانی<br>جان من تا اخر عمرویدیو بزارید',
#   'اونی که تو کیسه بود ایمان نبود. اون سرعت فقط مال جنه😭😂',
#   'Dj Khaled 🏌️',
#   'سلام میا تتو زدی',
#   'میالندی دقل باز زنده باد بر کوروش کبیر',
#   'میا با این مدل مو زیبا ترین ملکه🤗🥰❤',
#   '❤️',
#   'هنوز ولاگو ندیدم ولی میدونم میا داره تو حموم میکاپ میکنه، کورشم تا شب خوابه😂😂😂',
#   'ایمان داره حیف میشه😂😂',
#   'دیدن ویدیو هایه خانم کیمیا بااس خوش حال و سکته کردنه مرسی از ویدیو من ۱۱ سالمه',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=20m10s">20:10</a> کسایی که کنجکاو ان ببینن تتوی میا کجاس رو بازوی سمت چپش زیر لباسش🗿',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=11m23s">11:23</a> نمیکنه زندگیمو پای بسکتبال گذاشتم و دارم حرص میخورم',
#   'داداشم ایمان فقط😂😂😂 یعنی سه بار زدم عقب و باز مردم از خنده، ایمان جان موتور توربو روت وصله؟ 😂😂💔',
#   '🥺🤍🫀',
#   'وااااییی خیلییی خوب بووود😂✨️',
#   'بهترین زوج یوتوب 😍♥',
#   'عالیییییییییی',
#   'عشقین',
#   'امیدوارم همیشه خوش باشید:)',
#   'مسابقه تابستونی ما کردن یکی که به ما فوحش داداه 😂😂😂😂😂❤❤❤❤❤❤',
#   'سامبادی گیوومینی هایاههه اه 😂😂😂❤❤❤',
#   'ایمان لعنت بهت😂😂😂😂😂😂',
#   'صد بار نگا به فیلمات کردمه🗿🗿🗿',
#   'میا من هروز فقط نیگا میکنم ب چنلت و هیچی نمیشه:| ادیتر بگیر خیلی بهتر میشه:))))',
#   'میا بیشتر از این ولاگ هایی بذار که میایی صحبت میکنی و برنامه ریزی میکنی و .... خیلیییی خوبن!',
#   'بسکتبال اصلانم لوس نیس کوروش اجازه بده که نپذیرم 😅 چون سختیه خودشو داره تو تمرین ... و اینکه میا برنده بود 😂❤مرسی از ویدیو های خفنتون 😅',
#   'خواهر داری😮',
#   'کوروش تو بسکت فقط رانینگ می\u200cکرد 😂',
#   'نثنثحثخثخثخ۲خ خ خ خ خوفه',
#   'خار مادر بسکتبال⛹️\u200d♂️🏀🏀',
#   '\u200f\u202a<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=8m01s">8:01</a>\u202c\u200f  میای کیوتتتت🥺🌨',
#   'عالی بود 🎉',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=6m24s">6:24</a> کوروش همیشه یه چیزی بر نشون دادن به ما داره هیچوقن چیز میزاش تمومی ندارن😔😂💚',
#   'عررررر',
#   'Best video ❤',
#   'لوز گفت انقدر جق زدی به گوشت رسیده',
#   'اونایی رو تیشرت کوروشن واقعععا خودشوننن شت <a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=7m49s">7:49</a>',
#   'وایییی کوروشششششش😍😂&gt;&gt;&gt;&gt;&gt;',
#   'ویدیوهایی که میا راجب خودش حرف میزنه یه چیز دیگس🤩',
#   'شامپو🍶',
#   'بچه ها میا برام دعا کنید فردا نتایج نمونه دولتی میاد برام دعا کنید قبول شم اگر قبول شم مادرم خیلی خوشحال میشه😢',
#   'مادرت چیشد؟',
#   'زیبا و فرحبخش مثل همیشه🧡',
#   'وای جر خوردم با گلف بازی کردن میا😂😂😂😂',
#   'Summer',
#   'Woah😮',
#   'WoH😂',
#   '❤',
#   'چقدر خندیدم😂😂😂😂عشقید😂❤',
#   'GG My Bro🎉',
#   'منی که مثل سگ ذوق کردم😂',
#   'تابَستان',
#   'چرا احساس میکنم میا همش از کورش  کتک میخوره؟',
#   'بیشتر ولاگ میزاری',
#   'قشنگترینا🪄🤍',
#   'فوتبال بازی کنین',
#   'بهترین سرگرمی تابستونی؟ نه مرسی ما میا و کوروشو داریم👍🏻🤍',
#   'Nice',
#   'پادشاه کوروش بزرگ بهترین پادشاه جهان❤❤️🌹',
#   'Mia you are best hope',
#   'اصلا وقتی میام میبینم ویدیو گذاشتین نیشم باز میشه دیگه بسته نمیشه 😂<br>دوستتون دارم کلییی🥲❤',
#   'وای عالییییی بودددد😂😂😂❤️',
#   'So cool vid 🐷❤️',
#   'بچه های کوروش توپیا و میا لند به پا خیزید و کامنت بزارید ، برین کمپ اما غذا ببرید لطفا❤️',
#   'میا تو هر بازی:من تو این خوب نیستم..<br>میا که اون بازیو میبره😌🤝😂😂<br>ایول هیلی باخال بوددد اره بولینگو برینننن یه دستم وسطی با ایمان بریددددددد سپاسسسسسسس',
#   'من موقع دیدن ویدیو جدید  میا و کوروش : اسکیپ کردن تا قسمت کوروش',
#   'میا بازی واقعیه😂',
#   'بسکتبالیست ها:ما داریم اینجا زحمت میکشیم',
#   'کاش والیبال بازی میکردید😂',
#   'ایشالا که هیچ وقت مشکلی براتون پیش نیاد ولی به نظرم سبک زندگیتون جوره که یه مشکل چندان بزرگ پیش بیاد نمیتونین جمعش کنید پایدار باشید',
#   'منم تابستونام همیشه یه افسردگی ریزی میگیرم🗿🥸💔',
#   'man bay enghadr khobid🚶🏻\u200d♀️🦋',
#   'وای میا منم مدت هاست دلم کارای تابستونی میخوااااااد😢',
#   'میا لطفا جواب کامنتا رو بده 😢',
#   'بوس بهتوننننن***',
#   'کیا اسکیت رو یخ میخوان ✋🏻😂',
#   'عالی عشقید 🥰🥰',
#   'بسیار زیبا بود <br>عالی بود <br>بی نظیر بود',
#   'خیلی خوبین😂',
#   'فوتبال دستی بازیزکنید',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=9m07s">9:07</a><br>5_3_1  name of the basketball game',
#   '💖',
#   'کوروش اوباهت میزان از بین رفت😭',
#   'بهترین پرنسس میاس',
#   '🤘🔥❤️',
#   'چتری ها تو کوتاه کنننننن',
#   'عاشق تیشرتای جدید کوروشممممممم',
#   'خیلی حس پت و مت بهم میدید',
#   'خیلی ویدیو ها شون رو دوست دارم مخصوصا ویدیو های فوردنایت  ویدیو فوردتایت بیشتر بزار میا  دمت گرم👍💖',
#   'ولی خدایی ایمان هم خیلی باحاله',
#   'مرسی که همیشه مارو خوشحال میکنید👍🔥',
#   '😂😂😂😂',
#   'آهنگ رقصت خیلی باحاله مخصوصا کپی رایت خردش',
#   'کوروش و میا دله من رو شاد می\u200cکنن 🎉😌\U0001fa76',
#   '۲ عدد عشق❤',
#   'مثل همیشه عالی ❤❤❤❤',
#   'دوستون دارمممممممممم♡',
#   '.',
#   'خیلی وایب قشنگی داشت🔥😍',
#   'عالیه❤️\u200d🔥',
#   'بولینگ شما دوتا باید باحال باشه. من بولینگ میخوام',
#   'ایمانو بیشتر بیاریید',
#   '❤❤❤❤❤',
#   'ایمان خدا بود چ سرعتی 😂😂😂😂',
#   'میا اون میای سابق نیست',
#   'چقد کوروش رو اونجا گول میزنن چیز میز بهش میندازن 😂😂',
#   'بع. از این ویدئو ازتیم دانشگاهم انصراف دادم😂',
#   'مگه میشه یکی حتی بدون آرایش هم مثل زمان آرایش کرده زیبا باشه😍 واقعا حسودیم میشه به رابطه خوبتون و همچنین هم موقعی شما رو میبینم انگیزه زیادی میگیرم و خوشحال میشم❤️',
#   'نویس😁😂💙',
#   '❤❤❤',
#   'یه روز دیگه     یه صدا توی گوشم داره میگه <br>که میا و کوروش یه بار دیگه اومدن با یه ویدیو دیگه❤❤',
#   'میا ناراحت نشی ولی وقتی میبینمت تحریک میشم😍😍😍',
#   '😂❤❤❤',
#   '❤❤ عاشقتونم',
#   'بعد صد سال ویدئو میا کوروش اومد',
#   'میاخیلی دوست دارممممم❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'میا با شلوارک جین »»»»»»',
#   'یعنی فقط منم که تازه فهمیدم میا ، خواهر داره ؟ 😂 فک میکردم فقط ی برادر داری',
#   'سلامتی همه ی کوناندو ها',
#   '😂❤',
#   'میا بزرگ و پادشاه کبیر کوروش لطفاً یک ویدئو بازی با مجازات بزارید',
#   'میا +ختن  =ملکه یوتیوب',
#   '🤣🤣❤️❤️',
#   'من موقع مسابقه 3نفریتون چشامو بستم 2صدمه ثانیه باز کردم دیدم ایمان نیس😂😂😂نگو برنده شده',
#   'و من که به زور دارم کنکورو تحمل میکنم',
#   'Thanks',
#   'و من که به زور دارم کنکورو تحمل میکنم',
#   'میخوایم🥺Meme review میا ما',
#   'کوروششش و میا جذابترین زوج یوتوب ایراننن',
#   'I love you 😃🤍',
#   'ایمان رو بیشتر تو ویدیوهاتون بزارید و ولاگ بیرونیه بیشتری بزارید',
#   'Just mia',
#   'کوروش داداش پرچمت بالاست',
#   'واییییی',
#   'بازم میگم فک کنم خیلی ناراحتی',
#   'میا خیلی گوگولیه',
#   'مرسی میا و کوروش <br>دوستون دارممممم❤❤❤❤❤❤❤',
#   'من خودم خیلی دوسشون دارم ولی یکم خلاق باشین تو کامنتا',
#   'ای خدا کورش چقدر با ذوق از وسایلش تعریف میکنه😂❤<br>مرسی هستیننننننن',
#   'خیلی خوشحالممو',
#   'من خودم بسکتبالیست هستم تابحال انقدر دبل ندیده بودم 😂',
#   'میا تتوی جدیدت مبارک❤',
#   'بهترین یوتیوبر',
#   'بابا غیر ولاک یچی دیگ هم\u200cبذار',
#   'بچه ها میا خواهر داره؟😳',
#   'وقتی میبینم که خارجی ها کامنت گذاشتن😢❤',
#   'ولی من خیلییی دوستون دارم و کلی با ویدئو هاتون چیل میکنم و بلهه رقص صبحگاهی که حتما انجام میدم باتون🤝🏻😂🤍',
#   'بازم از این ویدیو ها بزارید ممنون 😁',
#   'Love you both ❤',
#   'بازم ایمان درست میگفت و پنج، سه، یک هستش بازی',
#   'خدایا شکرت باز ویدیوی جدید😂😍',
#   'میا قشنگ  معلومه ورزش میکنی از بدنت افرین ادامه بده❤❤❤❤❤❤❤❤❤❤❤❤',
#   'ممنونم ازتون <br>هر کاری کنید ما حمایتتون میکنیم ❤',
#   '❤❤',
#   'میا ارزومه از کفشای تو داشته باشم🥺🥲',
#   'حرفای میا باعث شد برم درس بخونم👩🏻\u200d🦯',
#   'میا اول ویدیو:کوروش رو برداریم ببریمش بیرون <br>میا وسط های ویدی : بابا خسته شدم بریم استراحت کنیم<br>میا آخر ویدیو : یکی این کوروش رو بشونه',
#   'میا اول ویدیو:کوروش رو برداریم ببریمش بیرون <br>میا وسط های ویدی : بابا خسته شدم بریم استراحت کنیم<br>میا آخر ویدیو : یکی این کوروش رو بشونه',
#   'منی که نمیدونستم میا خواهر داره🗿🗿',
#   'اسمش 5 3 2',
#   'گرده هام کنده شد با حرکت ایمان<br><a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m30s">15:30</a>',
#   'میا:بازیای تابستونه بگید<br>کوروش:اسکیت رو یخ',
#   '❤️\u200d🔥',
#   'تیشرت ها کی میاان؟😢😢😢',
#   'واااااااییییی کاش این ولاگ تا ابد ادامه داشته باشه🤦🏽\u200d♀️❤',
#   'ایمان زندگی قبلیش کانگرو بوده😂😂',
#   'زندگی میا و کوروش همه چی داره به جز یه چیز &quot;بچه&quot;',
#   'Shad bashid hamishe❤❤❤',
#   'میا جونم دلم خیلی برات تنگ شده بود 💖🥰',
#   'سلام میا جون <br>میشه توی ولاگ بعدی تون با ایمان به خونه انشرلی برین ؟؟❤❤❤',
#   '😂😂',
#   'یک دست فوتبال تو زمین درست که ایمان داورش باشه حق بود لایک کن به دستشون برسه',
#   'کی این دیالوگ رو یادشه <br><br>کیمیا و کوروش تا ابد و بری همیشه',
#   'هرکی بازی های چرت و پرت کوروشو میخاد لایک کنه 🙏😂',
#   'میا من تا چندوقت دیگه میام ونکوور باید دوست صمیمی فابریک خودم بشی بست میشینم دم خونتون 😁',
#   'زوج گوگولی دوس داشتنی من .',
#   'تنیسو برین',
#   'عرررر بلخرعععع',
#   'درود بر کوروش بزرگ وقتی حرف میزنه انرژی میگیرم ❤',
#   'من عاشقشونم و از اولین ویدیو\u200cی کیمیا باهاش بودم <a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=1m10s">1:10</a>',
#   'بابت حس خوبی که بهمون میدید یه دنیا تشکر❤️',
#   'نظر من این بود که برنده واقعی کورش بود',
#   'Amazing YouTuber btw❤',
#   '۲۱دیقه کمه شما باید یکساعت ویدیووو داشته باشیدددددد😂😂😂😂',
#   'جوری که کوروش تو بازیهای چرت پرت حرفیه ایه و تو بازی های واقعی داغون😂😂',
#   'دوباره عالییی',
#   'ایمااااااان😂😂😂😂',
#   'تموم شد😢پس پیش به سوی هری پاتر برای بار هزارم',
#   'خدایی دقت کردین میا ملکه میالنده کوروش هم پادشاه کوروشتوپیاست خوب برای همین کوروش پادشاه هردو سرزمین میا هم ملکه هردو سرزمین',
#   '<a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a>',
#   'میا میدونستی خیلی دوست دارم🥲❤❤',
#   'ممنون که همیشه حالمون رو خوب میکنید❤',
#   'والیباللل🐈',
#   'خدای من درست دیدم میا، ملکه ی دل ها ویدئو آپلود کرده؟  درود بر شما و پادشاه کورش عزیز❤',
#   '❤❤❤❤❤',
#   'همه قوانین اشتباه انجام دادین من خودم بسکتبالیستم دو دستی نمیشه دریبل زد دو نمیتونی توپ رو بگیری از دوباره دریبل بزنی',
#   'کوروش اگر تو پادشاه کوروشتوپیا هستی میا هم ملکه ی یوتویوب فارسی هست',
#   '❤❤',
#   'تو کل چنل میا اولین ویدیوعی که خوشم نیومد',
#   'داداش کجاش لوسه خدایی هی میگید <br>این همه با انرژی <br>خدایی برید ببینید بقیه دختر ها چجورین',
#   'دلیلشم لوس بودن رفتار میاعه😔',
#   'باه باه❤',
#   'خیلی واقعی و شفاف هستین🌱❤',
#   'Mia videos change my life😅😂',
#   'فرحبخششش❤😂',
#   'سامر تایم سد نسسس😂😂❤❤',
#   'دستای کیوت میااا🙂🥺😌',
#   'گلف بازی کردنتون عالی بود😂😂😂',
#   'خیلی وقته که ویدیو میم ریویو نذاشتید :(',
#   '😮',
#   'عالیییییی',
#   'ممنونم که ویدیو میزاری،خیلی وقت بود از ته دل نخندیده بودم:&gt;<br>موفق باشیدد<br>میالندی فور عوررر',
#   'Boseeee 💓',
#   '❤',
#   'عالی',
#   'میا تورو خدا می تونی بیشتر ویدیو بزار',
#   'کوروش چرا دیگه زنگوله رو نمیزنی 😢<br>بچها توروخدا لایک کنید پیام بیاد بالا تا میا و کوروش ببینن و کوروش بازم زنگوله رو بزنه ما دلمون تنگ شده 😊❤',
#   'سلام میا من یکی از طرفدار هات هستم میشه باهم ۱v1 یا بتل بازی کنیم با کوروش',
#   'عشقی میا🤍',
#   'کوروش بسکت انقدراهم سخت نیستتتتتت',
#   'به باسن میا توجه نکنید😂',
#   'مدل موهات خیلی قشنگه🥺😍',
#   'اون حرکتیم که همون اول میا رف اسمش سه گامهههه',
#   'من بسکتبالیستم و خیلی ذوق کردم که بازی کردینننن',
#   'چقد باحاله ایمان🤣🤣',
#   'عالیییی ❤❤ میا ارمی هستی تروخدا جواب بده من واقعا برام سواله',
#   'میا یه ویدیوی ری اکت به ویدیو های تو بزارین ❤️❤️❤️\u200d🩹❤️\u200d🩹',
#   'چقدر با بافت کیوت میشیییییی😢❤',
#   'iman yeho kangoro darunesh zad birun vasate bazi',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m13s">15:13</a> ایمان عالی بود 🤣',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=13m48s">13:48</a> من تو بچگی این بازیو انجام میدادم و بارها با کله فرود اومدم، من در آوردی نیستتت 😭😂',
#   'اولین کامنتمه',
#   'خیلی خوبی',
#   'میا خیلی دوست دارم',
#   '&lt;&lt;3',
#   'کاش اون بچه ای بودم که تازه موبایل گرفته و امروز اولین روزش توی یوتیوب بوده و میتونه تا چند روز ویدیوهای جدید ازتون بگیره.❤',
#   'Love you mia❤<br>You are so pretty and cute and I get a good vibe from you❤<br>Kourosh&#39;s game😂👍👌🏻',
#   'Love you❤',
#   'تو یه روز نیم میلیون بازدید . شما خدایید😂❤❤',
#   'حیف. منم کتابای داداشمو برمیدارم میخونم',
#   'واییی شما خیلی عالی اید<br>امیدوارم بینهایت عمر کنید❤❤',
#   'ایمان خیلی باحال رفت عالیییییی',
#   'من تو این ویدیو  فهنیدم میا فحش هم بلده و روز نره استفاده میکنه',
#   'عالییی پر از وایب خوبید🥺✨🤍',
#   'عالی هستین شما❤',
#   '🌹🌹',
#   'Next part 👌💥',
#   'Nice guys 👌❤️',
#   'میا خیلی خوب بود لطفا کلی دیگه ولاگ تابستونی بزار',
#   'همچی خوب بود تا یادم اومد تا هفته دیگه ویدیو نمیزارین',
#   '5,3,1 bazie iman doors mige:))))',
#   'میشه که کوروش مجازات بشه',
#   'love u guys &lt;3',
#   'Did you write your new tattoo? Tell us about it ❤',
#   'کامنتای ویدیو های میا و کومان همیشه اینطوریه که: مرسی که روزمون رو زیبا کردین مرسی که با وجودتون حالمون رو روشن کردین مرسی که جمعه هامون رو زیبا تر میکنین مرسی که...😂😂',
#   'کامنتای ویدیو های میا و کومان همیشه اینطوریه که: مرسی که روزمون رو زیبا کردین مرسی که با وجودتون حالمون رو روشن کردین مرسی که جمعه هامون رو زیبا تر میکنین مرسی که...😂😂',
#   'کامنتای ویدیو های میا و کومان همیشه اینطوریه که: مرسی که روزمون رو زیبا کردین مرسی که با وجودتون حالمون رو روشن کردین مرسی که جمعه هامون رو زیبا تر میکنین مرسی که...😂😂',
#   'ستاد مبارزه با اولین کامنت',
#   'عین سگ دلم براتون تنگ شده بوووووددددددد',
#   'میشه با کورش یا تنها فورتنایت بازی کنی',
#   'خوش به حالتون ما تو ایرانیم کله سرگرمیمون اینه که سرمون تو گوشیمون باشه خوش به حالتون که پول دارید 🥲\U0001fae0',
#   'دیگه ویدیو های چرت و پرت کوروش نمیزارید؟',
#   'عالی بودید مثل همیشه😍😍',
#   'عااالیییی😍😍😍',
#   'I don’t care 🤷',
#   'من الان آلمان آلمان هستم اینجا هوا خیلی خوب انگار تابستون نیست',
#   'تو بخش بسکتبال واقعن میا بهتره بسکتبالش',
#   'برین تنیس بی برو برگرد عاشقش میشین🎉🤗',
#   'بچه شیراز باخت نمیده🤌😂',
#   'فقط منم که به اسکیتر اون پشت توجه کردم؟خوش به حالشون زمین درس حسابی دارن',
#   'میا چجوری با وجود کوروش افسردگی میگیری😂😂',
#   'You&#39;re the best ❤',
#   'سی مشالله مشالله مشالله',
#   'سلام<br>یه ایده دارم.به نظرم برچسبای کوروشو توی پک تیشرتایی که میخواید بفرستید بزاریدشون.حالا یا همون چند تا که شانسی برا بعضیا در بیاد یا به اندازه همه تیشرتاتون',
#   '.🗿',
#   'سلاااااام میا من ویدیو هاتو دوست دارم واز ۲ سال پیش تو رو دونبال میکنم❤❤❤❤❤ عشق فورتنایت',
#   '...',
#   'ندیده لایک می\u200cشود😂😎♥️',
#   'بعد از ۲۰۰ سال اولین کامنت عمرم',
#   'love',
#   'Your dance is great',
#   'سلطان کوروش ❤من کوروش توپیایی هستم🗿🗿',
#   'میا حواست باشه یو وی افتاب زیاده<br>و خوشحالم بالاخره کوروش رشته ی مورد علاقه ی من رو بازی کرد بسکتبال 😊',
#   'میا چرا دیگه فورتنایت بازی نمی کنی ؟🥲🥲🥲🥲',
#   'خخخخیلی خوبید❤❤❤❤',
#   'ب\u200dَه بَه دی بای دی های میا جاااان 🥰🥰🥰❤️پر از حس و\u200cحال خوب',
#   'به عنوان کسی که یه کوچولو بسکتبال بلده خیلی اعصابم خورد شد. ببین اون حرفه\u200cای ها چطورین🤣',
#   ...],
#  'the_media': ['کروش کلی خطا کردی😂 رانینگ کردی توپ رو هی گرفتی دوباره دیریب میزدی😂👌',
#   'فوتبال بازی کنید',
#   'کل بازیشون دبل بود<a href="about:invalid#zCSafez"></a>',
#   'دو دستی ندیده بودم کسی بسکت بازی کنه<a href="about:invalid#zCSafez"></a>',
#   'کورووش دبل نکنننن',
#   'فقط اون پشت ایمان بدبخت',
#   'گودرتتتتت میا از بیرون جیمز هم بیشتره😂😂',
#   'ایمان : گودرتتتتت😂',
#   'و منی ک تابستون تموم شدو و تازه احساس تابستونی گرفتم😂',
#   'والیبال',
#   'کورش چقد خوش خطه',
#   'ایمان از ماتریکس خارج شد',
#   'بسکتبال جزو ۵ ورزش سخت دنیاس',
#   'نمی\u200cدونم ولی نمیتونم چشممو از باسن کوروش بردارم',
#   'ویدو بعدی برین والیبال 😅',
#   'ایمان پرواز کرد 😂😂😂😂',
#   'والیباللللل',
#   'کوروش مرز های شعر نویسی لرزید😂❤',
#   'عهههه مبین',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=5m26s">5:26</a>  واقعا خط کوروش فوقالعادست 😮',
#   'کورش یه مسابقه میزاره خودش برنده شه🗿😂',
#   'اسم چنل چیه؟<br>Miaplays<br>یعنی میا بازی می\u200cکند<br>ولی میا چیکار میکنه ولاگ میزاره با این اوضاع اسم چنل باید MiaVlogs باشه نه میا پلیز😂❤',
#   'FIBA  بعد دیدن این فیلم کل قوانین بسکتبال رو تغییر داد😂😂',
#   '3 5 2 : .... <br>: شوته منطقه ای <br>از هر جایگاه یه شوت میزنی',
#   'اون جا که فقط تو کیسه رفت ایمان😂😂😂😂😂❤',
#   'go with football⚽️🥅⚽️🥅🥅',
#   'کوروش  داری همچی را اشتباه  انجام می  دی',
#   'چقدر ذهنت درگیره 😬😬🤯🤯',
#   'لانا بعد خوندن میا خودکشی کرد..<br>شوخیه بخدا',
#   'مارم دعوت میکردید 😢',
#   'بچه ها کسی میدونه اون رو بازوی میا چیه',
#   'چرا این کارو میکنی با ترک <a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=0m55s">0:55</a> 😂❤',
#   'کوروش جر زن 🤣😭',
#   '\u200f\u202a<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m13s">15:13</a>\u202c\u200f ایمان فنر😅',
#   'Iman che sami bood',
#   'تو با وجود کوروش افسردگی گرفتی😂😂 پشمامممممممممم',
#   'بدون ارایش خوشگلتری دختر',
#   'راجب خواهرت بیشتر بگو <br>فک نمی\u200cکردم خواهر داشته باشی😂',
#   'میا مرد لوخترو که پشت سرتون بود فکر کنم دیدین 🤣🤣🤣🤣🤣🤣',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m31s">15:31</a> پاره شدم',
#   'I’m a bb team player',
#   'حرف های خیلی مثبت میزنی❤❤❤❤😯🧠',
#   'معلومه که تو بازی دومیه پسرا بهترن😂😐🙏',
#   'به به ❤',
#   'اعتماد به نفس میا تو ورزش غیر قابل تفسیره',
#   'اسکیت رو یخخخ',
#   'بعد از ۵ سال دنبال کردن میا تازه فهمیدم خواهر داره😂',
#   'واقعا عالی بود خیلی خندیدمم عاشقتونم:)♡',
#   'سر اون کیسه\u200cئه انقد خندیدم نزدیک بود بمیرم بس نفسم بالا نمیومددددد😂😂😂',
#   'تتو ی کوچولوت خیلی گوگولیه',
#   'ملکه میاااا',
#   'دست خط کروش از کع زندگیم قشنگ تره',
#   'فقط ایمان',
#   'بسکتبال کوروشتوپیا',
#   '😂😂❤❤🎉🎉😢😢😮😮😅😅😅😊😊خیلی عالی بود',
#   'بچه ها کسی میدونه چرا دماغ میا کجع ؟ عمل کرده اینجوری شده؟<br>در هر صورت خیلی نازه❤',
#   'به خدا اگه بخوای ادامه تحصیل بدی بلاکت میکنم',
#   'ایمان چاااابک😂😂😂',
#   'ولی این ترکیب ایمان و کوروش و میا',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m09s">15:09</a> ایمان اینجا عالی بود😂😂',
#   'میا و کوروش از ماتریکس خارج شود در تاریخ سبت شود',
#   'این چه مدل بسکتبال بازی کردنه دارم سکته میکنم (۱۰ ساله بسکتبال میرم )',
#   'برنده میا بود \u200cعععععععععع و اینکه بسکتبال خیلی راحت و نمی تونییییییی با دوتا دستت بزنی',
#   'دیگه عهد می کنم این ویدیو رو نبینم.😅',
#   'پشمام چرا میا آنقدر عقده ایی بدبخت😂😂😂 شوخی کردم موفق باشین❤❤',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=5m28s">5:28</a> عجب دست خطی داره کوروش. چقدر خفن بود !!!!❤🎉',
#   'چرا پای چشای میا انقد گود رفته',
#   'بسکتبال عشقه شما ها خرین اشتباه هم می رین و کوروش مثل خر می خندی🏀🏀🏀🏀🏀🏀🏀🏀',
#   'وای این ایمان چرا اینقدر عالیه آخه😂💙<br>همیشه تو ویدئو هاتون باشه خدایی',
#   'اگه روزی پام به کانادا وا شد حتما بهتون بسکتبال یاد میدم😂<br>و نه ورزش لوسی نیست ولی آره سطح بالاش واقعا سخته<br>و کوروش داشت کل بازی رو اشتباه بازی میکرد، نصف دبل نصف ترول😂',
#   'بسکتبالیست حرفی ای میالند یا کوروشتوپیا<br>اونایی که می گن میالند یه قلب آبی بزارن <br>اونایی که می گن کوروشتوپیا یه قلب زرد بزارن',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m20s">15:20</a> ایمان🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣😍',
#   'خواهان چراغ قوه های کوروش هستییمم!',
#   'من فقط منتظر این هستم که آریا داره میاد ونکوور و با میا کوروش ویدئو  بگیره😂😂😂😂😂دوتا شاه بقل هم آریا و کوروش شاه شاهان'],
#  'other': ['بدن درد شدید<br>تخت بیمارستان<br>ساعت ۱ صبح<br>اینجا اخر خطه<br>سرطان برد.<br>Rip me<br>Laugh at my funeral <br>So i laugh',
#   'بنازمم میااااااا🎉🎉',
#   'Perfect❤❤❤',
#   'Love u both.',
#   'بدترین تابستونم بود🥲🦦\u200f\u202a\u202c\u200f',
#   'یچیزی یادم رفت متاسفانه، شما تابستونم اکلیلی کردین💗🎀👼🏻',
#   '❤❤❤❤❤',
#   'Love you guys❤️',
#   '🔥',
#   '❤',
#   'خخخ',
#   'love you guys you arethe best perfect videos love u❤️',
#   'من که با رانینگ ها و دبل های کوروش و میا تو بسکتبال فشار میخوردم😁😁😁',
#   'میا چقدر خوب بلدی',
#   'اگر توپ رو هم بگیری راه بری راننینگ میشه که باز هم خطا هست😅😅😅😅😂😂',
#   'دبل خطاست',
#   'دو دستی دبل هست😅😅😅😅',
#   '❤❤',
#   'Mia my mental health isn&#39;t kinda good but your videos make me forget my problems  I&#39;ve been watching your videos for 4 years and still not tired of you your the best Mia!',
#   'Ytygxd',
#   'Mia is god 😭',
#   '❤',
#   '😍🤩😂🤣❤️',
#   'پر قانون ترین والیبالی ک تا به عمر دیدم:',
#   'لی لی😂😂😂😂😂',
#   'عالی',
#   'بهترین\u200cشنبه\u200cسال🥲',
#   'میا، قهرمان بازی های تابستانه🌼🌱',
#   '😂😂😂😂😂❤',
#   'عالیییییییی',
#   'یادمه قبلا میا با ps4فورتنایت پلی می کرد یادش بخیر',
#   'من بسکتبالیستم',
#   'خیلی قشنگ بود ممنون',
#   'عالی منتظر پارت سیو میا 🎉',
#   'راس میگه توپه رو دیدم اومد تهران خورد به پنجرم🥲😂love you guys 💚🦋',
#   'Thank you for making us fell better<br>I love you ❤',
#   'Great',
#   'مثل همیشههه پر از انرژی مثبت و وایب خوب ♥️😅',
#   'پارت بعد',
#   'this feels really good guys❤',
#   'Perfect',
#   '🤩🤣😂😍❤️',
#   '🤩🤣😂😍❤️',
#   'ویدیو هاتون خیلی خوبه',
#   'چه جالب منم همین فکر ها رو دارم این چند وقت از اول تابستون میا <br>درگیر این بودم که کار کنم یا عکاسی رو ادامه بدم یا درس بخونم',
#   'برین بیلیارد',
#   'بشخصه استخر رفتن تو تابستون بهم خیلی حال میده مخصوصا این پارکای ابی',
#   'انگار زندگی من رو میسازین با یه ویدیو برای یک هفته کامل <br>سه هفته بود نتونستم ببینم داشتم میکردم بخدا <br>یکی یکی دارم میبینم همش رو..مگه شماها چقدر میتونین فرشته باشین عشق ها ❤',
#   'فرحبخشششش',
#   'چرا دیکه گیم نمیزنیو یسریاشم مثل قدیما آپلود نمیکنی من نمیفهمممم🥲',
#   '💖💖💖💖💖💖💖🌓🌓🌓💖💖🌙',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m10s">15:10</a>   🤣🤣',
#   'والیییباللل بازی کنیییید ✨🥲😁',
#   'جوریکه با ویدیوهاتون روزمو میسازید&gt;&gt;&gt;&gt;',
#   ':)))',
#   'فوتبال بازی کنین',
#   'با ویدیوهای\u200c شما میرم تو یه دنیای دیگه و لذت میبرم مرسی که ویدیو میزارین ❤',
#   'cool',
#   'فوتبال',
#   'Perfect 🎉🎉🎉🎉🎉',
#   'مایکل جردن بعد از دیدن این ویدیو :<br>🕳️🧑🏿\u200d🦽',
#   'تیکه ای که کوروش نیست تو ویدیو بول شته',
#   'Salllammmm',
#   'Love',
#   'نوب سگ😂😂😂',
#   'لطفاً ایرهاکی بازی کنین',
#   '❤',
#   'Eshqid❤❤',
#   '🍉🍊',
#   'عالی',
#   'من ساعت ۱۲ شب درحال دیدن ویدیو های قبلی چون جدیدا تموم شدن ::::: مرسی که ارامشو بهم برگردوندین تا خوابم ببره ، خیلی دوستون دارممم',
#   'میا و کوروش جوری حالم رو خوب میکنن که هیچکس نمیتونه خوب کنه💖🤣😊',
#   'ایمان خرگوشی در چمن زار😂😂😂😂😂😂😂',
#   'خواستم بگم ک اون چراغ قوه دومیه رو من ۱۸ ساله هم دارم اصلا دست ساز نیست و در عرض ده دقیقه ام گرم میشه 😂',
#   'ام....میا فکر کنم ما همزاد هم هستیم، چون من دقیقا همه علاقه هام و سلیقه هام و هر اتفاقی که توی زندگیم افتاده دقیقا برای تو افتاده و حتی اسمامون و حتی تاریخ تولد هامون یکیه و منم ابانی  ام و طرفدار بی تی اس هم هستم و حتی سن هامون هم یکیه❤بخدا قسم میخورم واقعا میگم',
#   'جوری که کسلم و با دیدن ویدیو های میا از ته دلم لبخند میاد رو لبام&gt;&gt;&gt;',
#   'عمه ام تو حال خونمون جنازش افتاده دورش جم شدن و من روم نمیشه برم چون خندم میگیره نمیدونم چه مرگم شدهههههههههههههههههه😐',
#   'توروخدا دوباره بسکت بازی کنیدددد',
#   'به خدا بسکتبال این طوری نیست🥲'],
#  'comments': ['عکس خودتو گزاشتی تو بیو گرافیت',
#   'به تو هیچ ربطی نداره خر عرعر کن ببینم',
#   'سلطان خر ها',
#   'حواست باشه با سلطان چجوری حرف میزنی',
#   'ونکوور وست زندگی میکنید😅',
#   'سلامممم',
#   'با جرعت میتونم بگم بهترین اکیپ سه نفره میا کوروش ایمان🤣🗿',
#   'میا بایپولار الان جو گیر شده',
#   'نمیدونم چطوری انقدر خوبین',
#   'ولاگ فوتبال پارت دو🌵❤️\u200d🔥',
#   'خیلییی دوستون دارممم مرسی از حس خوبتون❤❤❤❤',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=15m35s">15:35</a> ایمان خیلی باحال بوددد😂😂',
#   'نصف شب اینقدر خندیدم همه بیدار شدن خیلی ویدیوی باحالی بود😂🤣🔥'],
#  'education': ['بازی بسکتبال اسمش پنج\u200cسه یکه',
#   'سلام به ملکه میا و پادشاه کوروش می خواستم یه سوال بپرسم <br>چجوری می\u200cتونم  داخل یوتیوب کار کونم؟؟؟',
#   'سلام کوروش  و میا <br>در مورد بسکتبال وقتی می خوای توپو به سمت دربازه یا بالا پرت کنی باید اول با دو دست توپو تقریبا تا نصفه بیاری بالا و بعد دست راست ادامه رو بره و پرتاب رو تا خم شدن انگشتان ادامه بده و در نیمه هاست که تماس دست دیگه باید آروم قطع شه <br>مگر نه تمام پرتاب هاتون اشتباه بود🤣🤣🤣'],
#  'toxic': ['کوروش راجب خودارضایی ویدیو بساز'],
#  'sports': ['Volleyball'],
#  'books': ['میا کوییدیچ در گذر زمان رو خوندی؟'],
#  'game': ['ایمان که اومد اصن بازی لول آپ شد😂❤love you guys 🔥',
#   'کوروش همه قوانین بسکتبال رو زیر پا گذاشت 😂😂',
#   'بسکتتون عالی بود😂ولی خداییش فکر نمیکردم میا سه گام بلد باشه.اون حالت خروس مانندم اسمش حالت تعادله و مربیه ما بشدت روش سختگیره😂',
#   'وای قشنگ بازی ای که باید تو سبد میپریدی عالی بودد😂',
#   'و منی که بسکتبالیستم از حرکات میا و کوروش در حین بازی بسیار عصبی شدم 😂😐',
#   'به شخصه به عنوان کسی که بسکتبال حرفه ای بازی می\u200cکنم این بیشتر راگبی بود 😂😂'],
#  'person': ['من حاضرم کل روز هرچی میا درست میکنه رو ببینم<br>میا لطفا ویدیوی انگیزشی بزارررررررر❤❤❤❤❤❤❤',
#   'فقط پریدن ایمان',
#   'دمتون گرم عاشقتونم',
#   'اره موهاتو رنگ کن چتری بزن خیلی بهت میاد❤',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=8m47s">8:47</a><br>ایمان مرسی که اومدییی🥺😂',
#   'وای میا به چشمت با اون براش نزن لطفااااااااااا',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=0m36s">0:36</a><br>میا چقدر بدون میکاپ خوشگلییییییییی😭😭😭✨✨',
#   'خواهررررررررر؟؟؟؟ چرا من نمیدونستمممممممممم🥲🥲🥲',
#   'وااااااااای عاشقتونم',
#   'میا شروع طوفانیی تو بسکتبال داشت 😂😭👏❤️',
#   '\u200f\u202a<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=9m37s">9:37</a>\u202c\u200f فک کنم منظور ایمان دارته',
#   'بعد این همه جر زنی کوروش یه جر زنی میا حقش بود',
#   'کوروش نه تو ویدیو ها سلام میکنه نه خدافظی🤣🤣🤣',
#   'سلام میا عاشق ویدوهاتم من میالندی هیتم و عاشق کتاب خوندنم ❤❤❤',
#   'میا بدون آرایش قشنگی با آرایش قشنگی<br>اصلن همه جوره خوشگلی',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=14m55s">14:55</a> کوروش مظلوم',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=5m56s">5:56</a> کوروش مظلوم',
#   'ایمان لجند👑😂',
#   'اتاق کوروش خداس😂🤌🏻<br>چه مانیتور خفنی داشت🥲',
#   'پشمام میا سیکس پک داره❤',
#   'سلام به میا و کوروش❤',
#   'زلم میالندی ها ما کوروش توپیایی ها نامرد نیستیم',
#   'گفتی مامانم و خواهرم؟؟؟ خواهر داره میاا؟؟؟',
#   'کوروش برای خودت تنها یه چنل بزنننننن',
#   '<a href="https://www.youtube.com/watch?v=sZo4TmfXiYY&amp;t=11m30s">11:30</a>کوروش انقدر رانینگ کردی دارم فشار میخورم ولی با این حال خیلی باحال بود',
#   'مگه میا خاهر داره؟',
#   'عالی میا و کوروش',
#   'یه سوال میا و کوروش کجا زندگی میکنن',
#   'چ دست خط کوروش قشنگه',
#   'میا خواهر داره ؟',
#   'چه برادر باحالی داشتی',
#   'منی ک تازه فهمیدم میا یک خواهرم دارهههههه\U0001fae5🤝',
#   'میا موهاش خیلی بهش میومد و کیوت شده بود اونوقت من اگ اونجوری ببندم موهامو شبیه اسکولا میشم 🗿',
#   'کوروش موقع شروع هر بازیه ورزشی:میا از همین الان باختی،همون کوروش بعد از خوردن خفن ترین دِریبل دنیا از میا:بابا باریکلاااااااا🗿🗿',
#   'مرسی از جفتتون <br>خیلی شادم می کنین❤🎉',
#   'شما بهترینید✨️\U0001faf6🏻<br>شاد باشیددد\U0001fae0']}

# %%
ds['sentiment'].keys()
# Out:
# dict_keys(['positive', 'neutral', 'null', 'negative'])

# %% [markdown]
# # Create Dataset Directory

# %%
dir = './dataset/'
if os.path.exists(dir) == False: os.mkdir(dir)
for key in ds.keys():
    if os.path.exists(dir+key) == False: os.mkdir(dir+key)
    for label in ds[key].keys():
        if os.path.exists(dir+key+'/'+label) == False: os.mkdir(dir+key+'/'+label)
        print(label+' '+str(len(ds[key][label])))
        count = 0
        for text in ds[key][label]:
            f = open(dir+key+'/'+label+'/'+str(count)+'.txt', "w")
            f.write(text)
            f.close()
            count+=1
# Out:
# positive 190
# neutral 69
# null 6334
# negative 21
# null 6396
# opinion 142
# command 19
# statement 38
# question 11
# other 6
# greeting 1
# announcement 1
# null 6400
# the_media 74
# other 79
# comments 13
# education 3
# toxic 1
# sports 1
# books 1
# game 6
# person 36

# %%
dir = './dataset_non_null/'
if os.path.exists(dir) == False: os.mkdir(dir)
for key in ds.keys():
    if os.path.exists(dir+key) == False: os.mkdir(dir+key)
    for label in ds[key].keys():
        if label != 'null':
            if os.path.exists(dir+key+'/'+label) == False: os.mkdir(dir+key+'/'+label)
            print(label+' '+str(len(ds[key][label])))
            count = 0
            for text in ds[key][label]:
                f = open(dir+key+'/'+label+'/'+str(count)+'.txt', "w")
                f.write(text)
                f.close()
                count+=1
# Out:
# positive 190
# neutral 69
# negative 21
# opinion 142
# command 19
# statement 38
# question 11
# other 6
# greeting 1
# announcement 1
# the_media 74
# other 79
# comments 13
# education 3
# toxic 1
# sports 1
# books 1
# game 6
# person 36
